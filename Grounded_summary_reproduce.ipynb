# %%
import os
from datetime import datetime
from time import time


class MyLog(object):
    def __init__(self, log_file='log/log_file', file_output=True, screen_output=True, reset=False):
        if not os.path.exists("log"):
            os.makedirs("log")
        self.st = time()
        self.log_file = log_file
        self.file_output = file_output
        self.screen_output = screen_output
        if reset:
            f = open(log_file, "w")
            f.close()

    def get_start(self):
        return self.st

    def set_start(self, st):
        self.st = st

    def reset(self):
        self.st = time()

    def get_time(self):
        return time() - self.st

    def set_file_output(self, file_output):
        self.file_output = file_output

    def set_screen_output(self, screen_output):
        self.screen_output = screen_output

    def set_log_file(self, log_file):
        self.log_file = log_file

    def log(self, msg, file_output=None, screen_output=None):
        if file_output is None:
            file_output = self.file_output
        if screen_output is None:
            screen_output = self.screen_output

        current_time = self.get_time()

        if file_output:
            f = open(self.log_file, "a+", encoding='utf-8')
            f.write(str(datetime.now()) + ' : ' + msg + '\n')
            f.close()

        if screen_output:
            print("%15.4f" % current_time, ':', msg)

# %%
import time

import numpy as np
import torch


def weights(c=0.8, k=64):
    r = c / k
    ret = []
    for i in range(k):
        w = 1 - i * r
        ret.append(w)
    return ret


parts = list(range(5, 100, 5))


def prepare_data_cuda(batch_data, config, func=None):
    ret = func(batch_data, config)
    cuda_ret = ()
    for it in list(ret):
        if type(it) != list:
            cuda_ret += (it.cuda(config.device),)
        else:
            cuda_ret += (it, )
    return cuda_ret


def offline(config, log):
    __, valid_set = get_data(config, log, mode="test")

    net = TokenLevelEncoder(config).cuda(config.device)
    if config.parallel:
        net = DataParallelModel(net)

    h = {}
    st = time.time()
    for batch_idx, batch_data in enumerate(valid_set):
        batch_chunks, batch_indices, batch_lengths, __ = \
            prepare_data_cuda(batch_data, config, prepare_offline_data)
        bsz, n, l = batch_chunks.shape
        k = config.offline_k // torch.cuda.device_count() // bsz
        m = n // k
        hiddens_np = np.empty((bsz, 0, config.doc_encoder.d_model), dtype=np.float64)
        for i in range(m):
            batch_chunks_ = batch_chunks[:, i * k: (i + 1) * k]
            with torch.no_grad():
                hiddens = net(batch_chunks_)
            if config.parallel:
                hiddens = torch.cat([it.to("cuda:0") for it in hiddens], dim=0)
            hiddens_np = np.concatenate([hiddens_np, hiddens.cpu().numpy()], axis=1)

        if m * k < n:
            batch_chunks_ = batch_chunks[:, m * k: n]
            with torch.no_grad():
                hiddens = net(batch_chunks_)
            if config.parallel:
                hiddens = torch.cat([it.to("cuda:0") for it in hiddens], dim=0)
            hiddens_np = np.concatenate([hiddens_np, hiddens.cpu().numpy()], axis=1)

        for i, (idx, l) in enumerate(zip(batch_indices, batch_lengths)):
            h[idx] = hiddens_np[i][:l, :]

        print(batch_idx + 1, hiddens_np.shape, batch_indices, (time.time() - st))
    name = "hidden_v_"+str(config.kernel_size)+"_"+str(config.stride)+"_"+config.window_type+".pkl"
    save_to_pkl(name, h)

# %%
import argparse
import os
from argparse import Namespace

import torch




def arg_loader():
    parser = argparse.ArgumentParser()

    """
        Actions: train/test/debug/offline
        Mode: ext/abs/swh/ret
        Mini: for debugging load less data
    """
    parser.add_argument('--do_train', action='store_true', help="Whether to run training")
    parser.add_argument('--do_test', action='store_true', help="Whether to run test")
    parser.add_argument('--debug', action="store_true")
    parser.add_argument('--offline', action='store_true')
    parser.add_argument('--decode', action='store_true')
    parser.add_argument('--example', action='store_true')
    parser.add_argument('--statistic', action='store_true')
    parser.add_argument('--create_ref', action='store_true')

    parser.add_argument('--mode', type=str, default='all')
    parser.add_argument('--offline_k', type=int, default=256)
    parser.add_argument('--epsilon', type=float, default=1.0)
    parser.add_argument('--ret_loss_per_token', action="store_true")
    parser.add_argument('--ignore_index', type=int, default=-1)
    parser.add_argument('--regularizer', type=int, default=1)
    parser.add_argument('--coef', type=float, default=0.1)

    parser.add_argument('--mini', action="store_true")
    parser.add_argument('--T_p', type=int, default=25)

    parser.add_argument('--Th', type=float, default=0.5)
    parser.add_argument('--cls_dim', type=int, default=256)

    parser.add_argument('--topk', type=int, default=3)
    parser.add_argument('--overlap', action="store_true")

    """
        Training Tricks:
            amp: Automatic Mixed Precision
            parallel: data-parallel
            device: default device
            n_workers: how many thread for data loading (current unavailable)
    """

    parser.add_argument('--amp', action='store_true', help="Whether or not to use amp during trianing")
    parser.add_argument('--parallel', action='store_true')
    parser.add_argument('--device', type=int, default=0)
    parser.add_argument('--n_workers', type=int, default=2)

    """
        Data Source: dataset/raw
            load: whether build from files or load from cache
            train/valid/test: the part of the dataset
            raw_train/valid/test: the path to raw file
            length_limit_input/output: maximum length
    """
    parser.add_argument('--load', action='store_true', help="Whether or not build from raw")

    # From dataset
    parser.add_argument('--from_dataset', action='store_true', help="From dataset")
    parser.add_argument('--dataset', type=str, default='podcasts')
    parser.add_argument('--train', type=str, default='train')
    parser.add_argument('--valid', type=str, default='valid')
    parser.add_argument('--test', type=str, default='test')

    # From Raw Files
    parser.add_argument('--from_raw', action='store_true', help="From raw text")
    parser.add_argument('--raw_train', type=str, default="raw_train.txt")
    parser.add_argument('--raw_valid', type=str, default="raw_valid.txt")
    parser.add_argument('--raw_test', type=str, default="raw_test.txt")

    # Truncated
    parser.add_argument('--input_limit', type=int, default=65536)
    parser.add_argument('--output_limit', type=int, default=128)
    parser.add_argument('--output_sent_limit', type=int, default=8)

    # Constrain
    parser.add_argument('--n_overlap_constrain', type=int, default=3)

    # Pre-ext parameters
    parser.add_argument('--threshold', type=float, default=0.2)

    """
        Pretrained Model Selection:
            --model_ext: roberta-base roberta-large
            --model_abs: facebook/bart-base facebook/bart-large facebook/bart-large-cnn
            --local: whether or not behind a firewall
        Current Version ext_model will takes bart encoder as its sentence encoder
    """
    parser.add_argument('--model_ext', type=str, default='roberta-large')
    parser.add_argument('--model_abs', type=str, default='facebook/bart-large')
    parser.add_argument('--local', action='store_true', help="Whether or not using local models")

    """
        Model Settings:
            Save Path
            Sliding Window
            Sampling (between ext part and abs part when training in mode "ext-abs")
            Extractor
    """
    # Save Path
    parser.add_argument('--main_path', type=str, default='./model')
    parser.add_argument('--abs_path', type=str, default='/abs')
    parser.add_argument('--ext_path', type=str, default='/ext')
    parser.add_argument('--swh_path', type=str, default='/swh')
    parser.add_argument('--ret_path', type=str, default='/ret')

    # Sliding Window
    parser.add_argument('--window_type', type=str, default="sent")
    parser.add_argument('--kernel_size', type=int, default=20)
    parser.add_argument('--stride', type=int, default=10)

    # Model Parameters
    parser.add_argument('--ext_type', type=str, default="TokenLevelEncoder")
    parser.add_argument('--d_query', type=int, default=1024)
    parser.add_argument('--d_key', type=int, default=1024)
    parser.add_argument('--d_att', type=int, default=1024)
    parser.add_argument('--d_inner', type=int, default=512)
    parser.add_argument('--d_model', type=int, default=1024)
    parser.add_argument('--dropout', type=float, default=0.1)
    parser.add_argument('--type_att', type=int, default=3)

    # Transformer Encoder
    parser.add_argument('--doc_n_layers', type=int, default=2)
    parser.add_argument('--doc_d_model', type=int, default=1024)
    parser.add_argument('--doc_n_head', type=int, default=16)
    parser.add_argument('--doc_d_ff', type=int, default=3072)
    parser.add_argument('--doc_max_len', type=int, default=1024)
    parser.add_argument('--doc_dropout', type=float, default=0.1)

    # Loss Parameters
    parser.add_argument('--label_smoothing', type=float, default=0.1)

    """
        Optimization:
            learning rate: 1e-5 (32), 1.224e-5(48), 3.4641e-5(384)
            weight decay
            adam_epsilon
            warmup steps: 5% to 10% of first epoch
    """

    parser.add_argument('--learning_rate', type=float, default=1e-5)
    parser.add_argument('--weight_decay', type=float, default=0.01)
    parser.add_argument('--adam_epsilon', type=float, default=1e-7)
    parser.add_argument('--warmup_steps', type=int, default=100)

    """
        Training:
            max epoch: 5, 10, 20
            batch_size: 1, 8, 16, 32
            checkPoint_Min/Freq: CheckPoint parameters
            save each epoch: for restore training (usually no need)
    """
    parser.add_argument('--max_epoch', type=int, default=20)
    parser.add_argument('--batch_size', type=int, default=1)
    parser.add_argument('--checkPoint_Min', type=int, default=0)
    parser.add_argument('--checkPoint_Freq', type=int, default=100)
    parser.add_argument('--save_each_epoch', action="store_true")

    # Testting Parameters
    parser.add_argument('--model', type=str, default='model_best.pth.tar')

    # Sentence Decoding Parameters
    parser.add_argument('--gen_max_len', type=int, default=128)
    parser.add_argument('--gen_min_len', type=int, default=20)
    parser.add_argument('--beam_size', type=int, default=4)
    parser.add_argument('--chunk_beam_size', type=int, default=4)
    parser.add_argument('--answer_size', type=int, default=4)
    parser.add_argument('--length_penalty', type=float, default=1.0)
    parser.add_argument('--no_repeat_ngram_size', type=int, default=3)

    args = parser.parse_args()
    # Build or Load
    args.build = not args.load

    # Special Tokens
    args.pad = 1
    args.UNK = 3
    args.cls = 0
    args.sep = 2
    args.BOS = 50261
    args.EOS = 50260
    args.MASK = 50264
    args.n_vocab = 50265

    # Doc Encoder
    args.doc_encoder = Namespace()
    args.doc_encoder.pre_training_model = args.model_ext
    args.doc_encoder.n_layers = args.doc_n_layers
    args.doc_encoder.d_model = args.doc_d_model
    args.doc_encoder.n_head = args.doc_n_head
    args.doc_encoder.d_ff = args.doc_d_ff
    args.doc_encoder.max_len = args.doc_max_len
    args.doc_encoder.dropout = args.doc_dropout
    args.doc_encoder.pad = args.pad
    args.doc_encoder.autoregressive = False

    # Local Pre-trained Models
    if args.local:
        args.model_ext = "../../pretrained_models/" + args.model_ext
        args.model_abs = "../../pretrained_models/" + args.model_abs

    # Data Loading options
    args.dataOptions = load_from_json("settings/dataset/" + str(args.dataset) + ".json")
    args.strategy = None

    # Model Save Path
    if args.mode == "ext":
        args.save_path = args.main_path + args.ext_path
    elif args.mode == "abs":
        args.save_path = args.main_path + args.abs_path
    elif args.mode == "swh":
        args.save_path = args.main_path + args.swh_path
    elif args.mode == "ret":
        args.save_path = args.main_path + args.ret_path
    else:
        args.save_path = args.main_path + "/ret-" + str(args.stride) + "-01"
    # Make Dirs
    if not os.path.exists(args.main_path):
        os.makedirs(args.main_path)

    if not os.path.exists(args.save_path):
        os.makedirs(args.save_path)

    # tricks
    # args.triGramTrick = not args.no_triGramTrick

    # Threshold
    if args.mode == "ext" and (args.do_train or args.do_test):
        name = "parts_" + str(args.kernel_size) + "_" + str(args.stride) + "_" + args.window_type + ".pt"
        parts = torch.load(name)
        args.T = list(parts.values())[args.T_p // 5 - 1]
        print(args.T)

    # print(args)
    return args

# %%
import torch



def get_data(config, log, mode='test'):
    print("get_data test")
    tokenizer = MyTokenizer(config)
    valid_set = Dataset(
        name=config.test,
        len_func=lambda x: sum(len(it) for it in x[0]),
        config=config,
        tokenizer=tokenizer,
        log=log,
        mode=mode
    )
    n_valid = len(valid_set)
    log.log("There are %d batches in valid data" % n_valid)
    return n_valid, valid_set


def get_network(config, log):
    # Model Setup
    log.log("Building Model")
    net = Retrieval(config)

    # Loading Parameter
    log.log("Loading Parameters")
    best_model = torch.load(config.save_path + "/" + config.model)
    new_stat_dict = {}
    for key, value in best_model["state_dict"].items():
        if key.startswith("module."):
            new_key = key[7:]
        else:
            new_key = key
        new_stat_dict[new_key] = value
    net.load_state_dict(new_stat_dict)
    log.log("Parameters Loaded")

    net = net.cuda(config.device)

    net.eval()
    log.log("Finished Build Model")
    return net


def test(config, log):
    tokenizer = MyTokenizer(config)
    config.batch_size = 1
    config.mode = "ret"
    net = get_network(config, log)
    _, valid_set = get_data(config, log)

    name = "hidden_v_" + str(config.kernel_size) + "_" + str(config.stride) + "_" + config.window_type + ".pkl"
    h_v = load_from_pkl(name)

    suffix = "_" + str(config.stride) + "_" + str(config.beam_size) + "_" + str(config.length_penalty)
    f = open("summary" + suffix + ".txt", "w")

    torch.cuda.empty_cache()

    for batch_idx, batch_data in enumerate(valid_set):
        print(batch_idx)
        answer, _ = beam_search(net, batch_data, config, h=h_v, output_others=True)

        ans = []
        first = True
        for sent in answer[2]:
            if first:
                ans.append(sent)
                first = False
            else:
                ans[-1].append(sent[0])
                ans.append(sent[1:])
        summary_text = " [SSPLIT] ".join(tokenizer.decode(sent) for sent in ans)
        if summary_text.endswith(" [SSPLIT] "):
            summary_text = summary_text[:-10]
        print(summary_text)
        print(summary_text, file=f)

    f.close()

# %%
import json
import random

import numpy as np
import torch
import torch.utils.data as Data



class MyDataset(Data.Dataset):
    def __init__(self, name, len_func, config, log, mode='train', prepare_func=None):
        self.name = name
        self.log = log
        self.len_func = len_func
        self.mode = mode
        self.prepare_func = prepare_func
        self.config = config

        self.build = config.build
        self.batch_size = config.batch_size

        self.path = config.dataOptions['Parts'][name]['path']
        self.sorted = config.dataOptions['Parts'][name]['sorted']
        self.shuffled = config.dataOptions['Parts'][name]['shuffled']

        self.n_data = 0
        self.data = []
        self.n_batch = 0
        self.batch = []
        self.batch_idx = []

    def sort_by_length(self):
        self.log.log('Start sorting by length')
        data = self.data
        number = self.n_data

        lengths = [(self.len_func(data[Index]), Index) for Index in range(number)]
        sorted_lengths = sorted(lengths)
        sorted_index = [d[1] for d in sorted_lengths]

        data_new = [data[sorted_index[Index]] for Index in range(number)]

        self.data = data_new
        self.log.log('Finish sorting by length')

    def shuffle(self):
        self.log.log('Start Shuffling')

        data = self.data
        number = self.n_data

        shuffle_index = list(range(number))
        random.shuffle(shuffle_index)

        data_new = [data[shuffle_index[Index]] for Index in range(number)]

        self.data = data_new
        self.log.log('Finish Shuffling')

    def gen_batches(self):
        batch_size = self.batch_size
        data = self.data
        number = self.n_data
        n_dim = len(data[0])

        number_batch = number // batch_size
        batches = []

        for bid in range(number_batch):
            batch_i = []
            for j in range(n_dim):
                data_j = [item[j] for item in data[bid * batch_size: (bid + 1) * batch_size]]
                batch_i.append(data_j)
            batches.append(batch_i)

        if number_batch * batch_size < number:
            if number - number_batch * batch_size >= torch.cuda.device_count():
                batch_i = []
                for j in range(n_dim):
                    data_j = [item[j] for item in data[number_batch * batch_size:]]
                    batch_i.append(data_j)
                batches.append(batch_i)
                number_batch += 1

        self.n_batch = number_batch
        self.batch = batches
        self.batch_idx = list(range(self.n_batch))

    def load(self):
        pass

    def after_load(self):
        if (self.mode != "test") and self.sorted:
            self.sort_by_length()
        if (self.mode != "test") and self.shuffled:
            self.shuffle()

        # Generate Batches
        self.log.log('Generating Batches')
        self.gen_batches()

        for_save = {
            "n_data": self.n_data,
            "Data": self.data,
            "n_batch": self.n_batch,
            "Batch": self.batch,
            "Batch_idx": self.batch_idx
        }

        save_to_pkl(self.name + ".cache", for_save)

    def batch_shuffle(self):
        random.shuffle(self.batch_idx)

    def __len__(self):
        if self.mode == 'train' or self.mode == 'valid':
            return self.n_batch
        return self.n_data

    def __getitem__(self, index):
        if self.prepare_func is None:
            return self.batch[self.batch_idx[index]]
        return self.prepare_func(self.batch[self.batch_idx[index]])


class Podcasts(MyDataset):
    def __init__(self, name, len_func, tokenizer, config, log, mode='train', prepare_func=None):
        super(Podcasts, self).__init__(name, len_func, config, log, mode, prepare_func)
        self.mini = config.mini
        self.input_limit = config.input_limit
        self.output_limit = config.output_limit
        self.kernel_size = config.kernel_size
        self.stride = config.stride

        self.tokenizer = tokenizer
        self.train_mode = config.mode
        self.threshold = config.threshold
        self.mode = mode

        # Loading Dataset
        if self.build:
            self.log.log('Building dataset %s from orignial text documents' % self.name)
            self.n_data, self.data = self.load()
            self.after_load()
            self.log.log('Finish Loading dataset %s' % self.name)
        else:
            self.log.log("Loading dataset %s from cached files" % self.name)
            for_load = load_from_pkl(self.name + ".cache")
            self.n_data = for_load["n_data"]
            self.data = for_load["Data"]
            self.n_batch = for_load["n_batch"]
            self.batch = for_load["Batch"]
            self.batch_idx = for_load["Batch_idx"]
            self.log.log('Finish Loading dataset %s' % self.name)

    @staticmethod
    def truncate(inputs, front, rear):
        if len(inputs) > front + rear:
            new_inputs = inputs[:front]
            if rear > 0:
                new_inputs += inputs[-rear:]
        else:
            new_inputs = inputs
        return new_inputs

    def load(self):
        input_file = open(self.path + ".json", "r", encoding='utf-8')
        data = []

        f = open(self.name + "_example.txt", "w")

        for index, line in enumerate(input_file):
            if self.mini and (index >= 5000):
                break
            data_i = json.loads(line)
            idx = data_i["episode_uri"]
            inputs_ = data_i["input"]
            outputs_ = data_i["output"]

            inputs = [self.tokenizer.encode(seg) for seg in inputs_]
            outputs = [self.tokenizer.encode(seq) for seq in outputs_]

            if len(inputs) == 0:
                print("Error: Input Empty at", index)
                continue

            if len(outputs) == 0 and self.mode != "test":
                print("Error: Output Empty at", index)
                continue

            lo = sum([len(it) for it in outputs])
            if lo < 10 and self.mode != "test":
                print("Error: Output is too short (%d < 10)." % lo, index)
                continue

            output_lengths = np.asarray([len(seq) for seq in outputs]).cumsum()
            t = 0
            while t + 1 < len(outputs) and output_lengths[t + 1] <= self.output_limit:
                t += 1

            outputs = outputs[:t + 1]

            if self.mode != "test" and apply_filter(inputs, outputs, self.config):
                print("Filter: Instance has too little overlap.", index)
                continue

            data.append([inputs, outputs, idx])

        f.close()
        return len(data), data

# %%
# !pip install packaging==21.3
# Out:
# Requirement already satisfied: packaging==21.3 in f:\users\bob2\anaconda3\envs\grnd\lib\site-packages (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in f:\users\bob2\anaconda3\envs\grnd\lib\site-packages (from packaging==21.3) (3.1.2)

# %%
import torch
import torch.nn as nn


class BinaryClsHead(nn.Module):
    def __init__(self, n_in, n_out, dropout):
        super().__init__()
        self.dense = nn.Linear(n_in, n_out)
        self.dropout = nn.Dropout(p=dropout)
        self.out_proj = nn.Linear(n_out, 1)

    def forward(self, x):
        x = self.dropout(x)
        x = self.dense(x)
        x = torch.tanh(x)
        x = self.dropout(x)
        x = self.out_proj(x)
        return x.squeeze(-1)


class MultiClsHead(nn.Module):
    def __init__(self, n_in, n_inner, n_out, dropout):
        super().__init__()
        self.dense = nn.Linear(n_in, n_inner)
        self.dropout = nn.Dropout(p=dropout)
        self.out_proj = nn.Linear(n_inner, n_out)

    def forward(self, x):
        x = self.dropout(x)
        x = self.dense(x)
        x = torch.tanh(x)
        x = self.dropout(x)
        x = self.out_proj(x)
        return x

# %%
import torch


def batch_index_select(x, idx):
    """
    :param x: *, n, Dim
    :param idx: *, k
    :return: *, k , Dim
    """
    idx_ = idx.unsqueeze(-1).expand(idx.shape + (x.shape[-1],))
    return torch.gather(x, -2, idx_)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable


class LabelSmoothing(nn.Module):
    def __init__(self, config):
        super(LabelSmoothing, self).__init__()
        self.crit = nn.KLDivLoss(size_average=False)
        self.pad_idx = config.pad
        self.confidence = 1.0 - config.label_smoothing
        self.smoothing = config.label_smoothing
        self.size = config.n_vocab

    def forward(self, predicts, target):
        assert self.size == predicts.size(1)
        dist = torch.full_like(predicts, self.smoothing / (self.size - 2))
        dist.scatter_(1, target.data.unsqueeze(1), self.confidence)
        dist[:, self.pad_idx] = 0
        mask_idx = torch.nonzero(target.data == self.pad_idx)
        if mask_idx.dim() > 0:
            dist.index_fill_(0, mask_idx.squeeze(), 0.0)
        return self.crit(predicts, Variable(dist, requires_grad=False))


class KLDivLoss(nn.Module):
    def __init__(self, config):
        super(KLDivLoss, self).__init__()
        self.crit = LabelSmoothing(config)

    def forward(self, predicts, target, norm=1.0):
        loss = self.crit(predicts.contiguous().view(-1, predicts.size(-1)), target.contiguous().view(-1))
        return loss / norm


class BCELoss(nn.Module):
    def __init__(self):
        super(BCELoss, self).__init__()
        self.crit = nn.BCELoss(reduction='sum')

    def forward(self, input, target, norm= 1.0):
        return self.crit(input, target) / norm


class BCEWithLogitsLoss(nn.Module):
    def __init__(self):
        super(BCEWithLogitsLoss, self).__init__()

    def forward(self, inputs, target, weights=None, norm=1.0):
        inputs = inputs.reshape(-1)
        target = target.reshape(-1)
        weights = weights.reshape(-1)
        return F.binary_cross_entropy_with_logits(inputs, target, weights, reduction="sum") / norm


class CrossEntropy(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.ignore_index = config.ignore_index
        self.crit = nn.CrossEntropyLoss(ignore_index=config.ignore_index, reduction="sum")

    def forward(self, pred, target):
        target = target.reshape(-1)
        num = target.shape[0]
        pred = pred.reshape(num, -1)
        return self.crit(pred, target)


class AdjacentRegularizer(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.ignore_index = config.ignore_index

    def forward(self, pred, tgt_indices, tgt_mask, src_mask):
        """
            pred: bsz, tgt_len, src_len
            target_indices: bsz, n
            tgt_mask: bsze, n
            src_mask: bsz, src_len
        """
        if tgt_indices.shape[1] < 2:
            return 0
        pred_ = batch_index_select(pred, tgt_indices)
        pred_ += (src_mask.unsqueeze(1) - 1) * 1e6
        prob = torch.softmax(pred_, dim=-1)
        prob_sum = torch.cumsum(prob, dim=-1)
        diff = prob_sum[:, 1:, :] - prob_sum[:, :-1, :]
        #print(diff.shape, tgt_mask.shape, src_mask.shape)
        #diff = torch.where(diff > 0, diff, torch.zeros_like(diff))
        loss = torch.relu(diff) * tgt_mask.unsqueeze(2) * src_mask.unsqueeze(1)
        return loss.sum()


class CrossEntropyWithRegularizer(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.coef = config.coef
        self.crit = CrossEntropy(config)
        if config.regularizer == 0:
            self.regularizer = None
        elif config.regularizer == 1:
            self.regularizer = AdjacentRegularizer(config)

    def regu(self, *args):
        if self.regularizer is None:
            return 0
        return self.regularizer(*args)

    def loss(self, *args):
        return self.crit(*args)

    def forward(self, pred, target, tgt_indices, tgt_mask, src_mask, norm_loss=1.0, norm_regu=1.0):
        loss = self.crit(pred, target) / norm_loss
        regu = self.regu(pred, tgt_indices, tgt_mask, src_mask) / norm_regu

        if loss < 0:
            print("Negative Loss Error", norm_loss)

        if regu < 0:
            print("Negative Regu Error", norm_regu)
        return loss + self.coef * regu

# %%
import math
import torch
import torch.nn as nn



class CrossAttention(nn.Module):
    """
        Attention Score = q^T W k + v^T tanh(W'[q; k] + b)
                       ~= (q^T U) (V^T k) + v^T tanh(W'[q; k] + b)

        Type of Attention:
            1: linear
            2: bilinear
            3: linear + bilinear
    """

    def __init__(self, config):
        super().__init__()
        self.type_att = config.type_att
        n_query = config.d_query
        n_key = config.d_key
        n_out = config.d_att

        self.bi_linear_query = nn.Linear(n_query, n_out)
        self.bi_linear_key = nn.Linear(n_key, n_out)

        self.linear_query = nn.Linear(n_query, n_out)
        self.linear_key = nn.Linear(n_key, n_out)
        self.att = nn.Linear(n_out, 1)

    def low_rank_bi_linear(self, query, key):
        """
            Relevancy Score
            Low Rank Bi-Linear Attention Implementation

            query: bsz, num_q, dim_q
            key: bsz, num_k, dim_k
            att_logits: bsz, num_q, num_k

            att_logits = q^T W k ~= q^T (U V^T) k = (q^T U) (V^T k)
        """
        query = self.bi_linear_query(query)
        # bsz, num_q, dim
        key = self.bi_linear_key(key)
        # bsz, num_k, dim

        d_k = query.shape[-1]
        logits = torch.matmul(query, key.transpose(-2, -1)) / math.sqrt(d_k)
        return logits

    def linear(self, query, key):
        """
            Saliency Score
            Linear Attention Implementation

            query: bsz, num_q, dim_q
            key: bsz, num_k, dim_k
            att_logits: bsz, num_q, num_k

            att_logits = v^T tanh(W'[q; k] + b)
        """
        query = self.linear_query(query).permute(0, 2, 1).unsqueeze(-1)
        key = self.linear_key(key).permute(0, 2, 1).unsqueeze(-2)
        activation = (query + key).permute(0, 2, 3, 1)
        hidden = torch.tanh(activation)
        logits = self.att(hidden)
        return logits.squeeze(-1)

    def forward(self, query, key):
        ret = 0
        if self.type_att & 1 > 0:
            a = self.linear(query, key)
            ret += a
        if self.type_att & 2 > 0:
            b = self.low_rank_bi_linear(query, key)
            ret += b
        return ret


class Retrieval(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.config = config
        self.mode = config.mode
        self.extractor = Extractor(config)
        self.abstracter = Abstracter.from_pretrained(config.model_abs)
        self.switch = BinaryClsHead(config.d_model * 2, config.d_inner, config.dropout)
        self.retrieval = CrossAttention(config)
        self.epsilon = config.epsilon

    def set_mode(self, mode):
        """
            mode: str
                ext: only extractor parameters
                abs: only abstractor parameters
                ret: retrieval parameters
                swh: switch parameters
        """
        self.mode = mode
        for para in self.parameters():
            para.requires_grad = False

        if self.mode == "ext":
            for para in self.extractor.parameters():
                para.requires_grad = True
        elif self.mode == "abs":
            for para in self.abstracter.parameters():
                para.requires_grad = True
        elif self.mode == "ret":
            for para in self.retrieval.parameters():
                para.requires_grad = True
        elif self.mode == "swh":
            for para in self.switch.parameters():
                para.requires_grad = True

    def get_mode(self):
        return self.mode

    def retrieve(
            self,
            # Extractor
            chunk_input_ids=None,
            chunk_hidden=None,
            chunk_attention_mask=None,
            salience=None,
            # Abstracter
            hidden=None,
            src_mask=None,
    ):
        if salience is None:
            with torch.no_grad():
                # bsz, n_key
                salience = self.extractor(
                    chunk_input_ids=chunk_input_ids,
                    chunk_hidden=chunk_hidden,
                    chunk_attention_mask=chunk_attention_mask
                )
        if src_mask is None:
            src_mask = torch.ones_like(salience)

        src_mask_ = (src_mask.unsqueeze(1)-1) * 1e6
        relevance = self.retrieval(hidden, chunk_hidden)
        attention = torch.log_softmax(relevance + self.epsilon * salience.unsqueeze(1) + src_mask_, dim=-1)
        return attention

    def forward(
            self,
            # Extractor
            chunk_input_ids=None,
            chunk_hidden=None,
            chunk_attention_mask=None,
            # Abstracter
            input_ids=None,
            decoder_input_ids=None,
            encoder_attention_mask=None,
            # Decoding
            encoder_outputs=None,
            past_key_values=None,
            inputs_embeds=None,
            decoder_inputs_embeds=None,
            use_cache=None,
            output_attentions=None,
            output_hidden_states=None,
            return_dict=None,
            # Switch
            decoder_labels=None,
            # Retrieval
            src_mask=None,
            salience=None,
    ):
        if self.mode == "ext":
            return self.extractor(
                chunk_input_ids=chunk_input_ids,
                chunk_hidden=chunk_hidden,
                chunk_attention_mask=chunk_attention_mask
            )
        elif self.mode == "abs":
            return self.abstracter(
                input_ids=input_ids,
                decoder_input_ids=decoder_input_ids,
                encoder_attention_mask=encoder_attention_mask,
                encoder_outputs=encoder_outputs,
                past_key_values=past_key_values,
                inputs_embeds=inputs_embeds,
                decoder_inputs_embeds=decoder_inputs_embeds,
                use_cache=use_cache,
                output_attentions=output_attentions,
                output_hidden_states=output_hidden_states,
                return_dict=return_dict,
                hidden_only=False
            )
        else:
            with torch.no_grad():
                hidden = self.abstracter(
                    input_ids=input_ids,
                    decoder_input_ids=decoder_input_ids,
                    encoder_attention_mask=encoder_attention_mask,
                    encoder_outputs=encoder_outputs,
                    past_key_values=past_key_values,
                    inputs_embeds=inputs_embeds,
                    decoder_inputs_embeds=decoder_inputs_embeds,
                    use_cache=use_cache,
                    output_attentions=output_attentions,
                    output_hidden_states=output_hidden_states,
                    return_dict=return_dict,
                    hidden_only=True
                )
            if self.mode == 'ret':
                return self.retrieve(
                    chunk_input_ids=chunk_input_ids,
                    chunk_hidden=chunk_hidden,
                    chunk_attention_mask=chunk_attention_mask,
                    salience=salience,
                    hidden=hidden,
                    src_mask=src_mask,
                )
            elif self.mode == "swh":
                next_embedding = self.abstracter.model.shared(decoder_labels) * self.abstracter.model.embed_scale
                return self.switch(torch.cat([hidden, next_embedding], dim=-1))

    def adjust_logits_during_generation(self, logits, cur_len, max_length):
        if cur_len == 1:
            self._force_token_ids_generation(logits, self.config.cls)
        if cur_len == max_length - 1 and self.config.sep is not None:
            self._force_token_ids_generation(logits, self.config.sep)
        return logits

    def _force_token_ids_generation(self, scores, token_ids) -> None:
        """force one of token_ids to be generated by setting prob of all other tokens to 0"""
        if isinstance(token_ids, int):
            token_ids = [token_ids]
        all_but_token_ids_mask = torch.tensor(
            [x for x in range(self.config.n_vocab) if x not in token_ids],
            dtype=torch.long,
            device=next(self.parameters()).device,
        )
        assert len(scores.shape) == 2, "scores should be of rank 2 with shape: [batch_size, vocab_size]"
        scores[:, all_but_token_ids_mask] = -float("inf")

# %%
import math
from copy import deepcopy as cp

import torch
import torch.nn as nn
from torch.autograd import Variable
from torch.nn import functional as F


def clones(module, n):
    return nn.ModuleList([cp(module) for _ in range(n)])


def attention(query, key, value, mask=None, dropout=None):
    d_k = query.size(-1)
    scores = torch.matmul(query, key.transpose(-2, -1)) / math.sqrt(d_k)
    if mask is not None:
        scores = scores.masked_fill(mask == 0, -6e4)
    attn = F.softmax(scores, dim=-1)
    if dropout is not None:
        attn = dropout(attn)
    return torch.matmul(attn, value), attn


class MultiHeadAttention(nn.Module):
    def __init__(self, config):
        super(MultiHeadAttention, self).__init__()

        self.d_model = config.d_model
        self.n_head = config.n_head
        self.d_k = config.d_model // config.n_head

        self.linears = clones(nn.Linear(self.d_model, self.d_model), 4)
        self.dropout = nn.Dropout(p=config.dropout)

    def forward(self, query, key, value, mask=None):
        if mask is not None:
            mask = mask.unsqueeze(1)
        batch_size = query.size(0)

        query, key, value = [l(x).reshape(batch_size, -1, self.n_head, self.d_k).transpose(1, 2)
                             for l, x in zip(self.linears, (query, key, value))]
        x, attn = attention(query, key, value, mask=mask, dropout=self.dropout)
        x = x.transpose(1, 2).contiguous().reshape(batch_size, -1, self.n_head * self.d_k)
        return self.linears[3](x), attn


class PositionwiseFeedForward(nn.Module):
    def __init__(self, config):
        super(PositionwiseFeedForward, self).__init__()

        self.w_1 = nn.Linear(config.d_model, config.d_ff)
        self.w_2 = nn.Linear(config.d_ff, config.d_model)
        self.dropout = nn.Dropout(p=config.dropout)

    def forward(self, x):
        return self.w_2(self.dropout(F.relu(self.w_1(x))))


class SelfAttentionBlock(nn.Module):
    def __init__(self, config):
        super(SelfAttentionBlock, self).__init__()

        self.norm = nn.LayerNorm(config.d_model)
        self.attn = MultiHeadAttention(config)
        self.dropout = nn.Dropout(p=config.dropout)

    def forward(self, x, mask):
        x_ = self.norm(x)
        x_, attn = self.attn(x_, x_, x_, mask)
        return self.dropout(x_) + x, attn


class SourceAttentionBlock(nn.Module):
    def __init__(self, config):
        super(SourceAttentionBlock, self).__init__()

        self.norm = nn.LayerNorm(config.d_model)
        self.attn = MultiHeadAttention(config)
        self.dropout = nn.Dropout(p=config.dropout)

    def forward(self, x, m, mask):
        x_ = self.norm(x)
        x_, attn = self.attn(x_, m, m, mask)
        return self.dropout(x_) + x, attn


class FeedForwardBlock(nn.Module):
    def __init__(self, config):
        super(FeedForwardBlock, self).__init__()

        self.norm = nn.LayerNorm(config.d_model)
        self.feed_forward = PositionwiseFeedForward(config)
        self.dropout = nn.Dropout(p=config.dropout)

    def forward(self, x):
        x_ = self.norm(x)
        x_ = self.feed_forward(x_)
        return self.dropout(x_) + x


class EncoderBlock(nn.Module):
    def __init__(self, config):
        super(EncoderBlock, self).__init__()
        self.self_attn = SelfAttentionBlock(config)
        self.feed_forward = FeedForwardBlock(config)

    def forward(self, x, mask):
        x, attn = self.self_attn(x, mask)
        x = self.feed_forward(x)
        return x, attn


class DecoderBlock(nn.Module):
    def __init__(self, config):
        super(DecoderBlock, self).__init__()

        self.self_attn = SelfAttentionBlock(config)
        self.src_attn = SourceAttentionBlock(config)
        self.feed_forward = FeedForwardBlock(config)

    def forward(self, x, m, src_mask, tgt_mask):
        x, attn_tgt = self.self_attn(x, tgt_mask)
        x, attn_src = self.src_attn(x, m, src_mask)
        x = self.feed_forward(x)
        return x, attn_src, attn_tgt


class Encoder(nn.Module):
    def __init__(self, config):
        super(Encoder, self).__init__()

        self.layers = clones(EncoderBlock(config), config.n_layers)
        self.norms = clones(nn.LayerNorm(config.d_model), config.n_layers)

    def forward(self, x, mask):
        outputs = []
        attns = []
        for layer, norm in zip(self.layers, self.norms):
            x, attn = layer(x, mask)
            outputs.append(norm(x))
            attns.append(attn)
        return outputs, attns


class PositionalEmbedding(nn.Module):
    def __init__(self, config):
        super(PositionalEmbedding, self).__init__()

        p2e = torch.zeros(config.max_len, config.d_model)
        position = torch.arange(0.0, config.max_len).unsqueeze(1)
        div_term = torch.exp(torch.arange(0.0, config.d_model, 2) * (- math.log(10000.0) / config.d_model))
        p2e[:, 0::2] = torch.sin(position * div_term)
        p2e[:, 1::2] = torch.cos(position * div_term)

        self.register_buffer('p2e', p2e)

    def forward(self, x):
        shp = x.size()
        emb = Variable(torch.index_select(self.p2e, 0, x.reshape(-1)), requires_grad=False).reshape(shp + (-1,))
        return emb


class Transformer(nn.Module):
    def __init__(self, config):
        super(Transformer, self).__init__()
        self.p2e = PositionalEmbedding(config)
        self.encoder = Encoder(config)

    def forward(self, input_emb, position_ids, attention_mask):
        # position embedding projection
        projection = self.p2e(position_ids) + input_emb
        return self.encoder(projection, attention_mask)

# %%
from copy import deepcopy as cp


def mapping_tokenize(s, t):
    st = 0
    ed = 0
    mapping = []
    mapping_idx = []
    for idx, token in enumerate(s):
        token_ = token.lower()
        prefix = "".join([piece.replace('##', '') for piece in t[st:ed + 1]])
        while token_.startswith(prefix):
            ed += 1
            if ed >= len(t):
                break
            prefix = "".join([piece.replace('##', '') for piece in t[st:ed + 1]])
        if (ed - st > 1) or (sum(1 for c in token if c.isupper()) > 1) or (idx > 0):
            mapping_idx.append([(st, ed), idx])
            mapping.append([cp(t[st:ed]), token])
        st = ed
    return mapping


def detokenize(text, mapping):
    if mapping is None:
        return text
    text = " " + text
    for one_mapping in mapping:
        keys = "".join([key.replace('##', '') if key.startswith('##') else ' ' + key for key in one_mapping[0]])
        value = ' ' + one_mapping[1]
        text = text.replace(keys, value)
    text = list(text[1:])
    if len(text) > 0:
        text[0] = text[0].upper()
        text = "".join(text)
    return text

# %%
def get_n_gram(seq, n):
    return list(zip(*[seq[i:] for i in range(n)]))


def do_tricks(preds, source, target, config):
    ban_ids = []

    # n_gram_blocking
    if config.no_repeat_ngram_size == 1:
        ban_ids = list(set(target))
    if (config.no_repeat_ngram_size > 1) and (len(target) >= config.no_repeat_ngram_size):
        current_n_grams = get_n_gram(target, config.no_repeat_ngram_size)
        for n_gram in current_n_grams:
            if all(t_token == ng_token for t_token, ng_token in zip(target[1 - config.no_repeat_ngram_size:], n_gram)):
                ban_ids.append(n_gram[-1])

    # min_length
    if len(target) < config.gen_min_len:
        ban_ids.append(config.sep)

    for idx in ban_ids:
        preds[idx] = -float("inf")

    # blocking NAN and INF
    preds[preds != preds] = -1e9
    preds[preds == float("inf")] = -1e9

    return preds


def trigram_blocking(preds, target, config):
    ban_ids = []
    if config.triGramTrick and len(target) > 2:
        current_tri_grams = get_n_gram(target, 3)
        for tri_gram in current_tri_grams:
            if (target[-2] == tri_gram[0]) and (target[-1] == tri_gram[1]):
                ban_ids.append(tri_gram[2])

    for idx in ban_ids:
        preds[idx] = -1e9

    return preds

# %%
import json
import pickle
import shutil

import torch


# IO
def load_from_json(filename):
    f = open(filename, 'r', encoding='utf-8')
    data = json.load(f, strict=False)
    f.close()
    return data


def save_to_json(filename, data):
    f = open(filename, 'w', encoding='utf-8')
    json.dump(data, f, indent=4)
    f.close()
    return True


def save_to_pkl(filename, data):
    with open(filename, 'wb')as f:
        pickle.dump(data, f)
    return


def load_from_pkl(filename):
    with open(filename, 'rb') as f:
        data = pickle.load(f)
    return data


def write_file(filename, massage):
    with open(filename, 'w', encoding='utf-8') as f:
        f.write(massage)
    return True


def save_check_point(state, is_best, path='.model', file_name='latest.pth.tar', mode=None):
    if mode is None:
        name = path + '/' + file_name
        torch.save(state, name)
        if is_best:
            shutil.copyfile(name, path + '/model_best.pth.tar')
            shutil.copyfile(name, path + '/model_best_epoch_' + str(state['epoch']) + '.pth.tar')
    else:
        name = path + '/' + mode + '_' + file_name
        torch.save(state, name)
        if is_best:
            shutil.copyfile(name, path + '/' + mode + '_model_best.pth.tar')
            shutil.copyfile(name, path + '/' + mode + '_model_best_epoch_' + str(state['epoch']) + '.pth.tar')

# %%
#+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Created by: Hang Zhang, Rutgers University, Email: zhang.hang@rutgers.edu
# Modified by Thomas Wolf, HuggingFace Inc., Email: thomas@huggingface.co
# Copyright (c) 2017-2018
#
# This source code is licensed under the MIT-style license found in the
# LICENSE file in the root directory of this source tree
#+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

"""Encoding Data Parallel"""
import functools
import threading

import torch
import torch.cuda.comm as comm
from torch.autograd import Variable, Function
from torch.nn.parallel._functions import Broadcast
from torch.nn.parallel.data_parallel import DataParallel
from torch.nn.parallel.distributed import DistributedDataParallel
from torch.nn.parallel.parallel_apply import get_a_var

torch_ver = torch.__version__[:3]

__all__ = ['allreduce', 'DataParallelModel', 'DataParallelCriterion',
           'patch_replication_callback']


def allreduce(*inputs):
    """Cross GPU all reduce autograd operation for calculate mean and
    variance in SyncBN.
    """
    return AllReduce.apply(*inputs)


class AllReduce(Function):
    @staticmethod
    def forward(ctx, num_inputs, *inputs):
        ctx.num_inputs = num_inputs
        ctx.target_gpus = [inputs[i].get_device() for i in range(0, len(inputs), num_inputs)]
        inputs = [inputs[i:i + num_inputs] for i in range(0, len(inputs), num_inputs)]
        # sort before reduce sum
        inputs = sorted(inputs, key=lambda i: i[0].get_device())
        results = comm.reduce_add_coalesced(inputs, ctx.target_gpus[0])
        outputs = comm.broadcast_coalesced(results, ctx.target_gpus)
        return tuple([t for tensors in outputs for t in tensors])

    @staticmethod
    def backward(ctx, *inputs):
        inputs = [i.data for i in inputs]
        inputs = [inputs[i:i + ctx.num_inputs]
                 for i in range(0, len(inputs), ctx.num_inputs)]
        results = comm.reduce_add_coalesced(inputs, ctx.target_gpus[0])
        outputs = comm.broadcast_coalesced(results, ctx.target_gpus)
        return (None,) + tuple([Variable(t) for tensors in outputs for t in tensors])


class Reduce(Function):
    @staticmethod
    def forward(ctx, *inputs):
        ctx.target_gpus = [inputs[i].get_device() for i in range(len(inputs))]
        inputs = sorted(inputs, key=lambda i: i.get_device())
        return comm.reduce_add(inputs)

    @staticmethod
    def backward(ctx, grad_output):
        return Broadcast.apply(ctx.target_gpus, grad_output)


class DistributedDataParallelModel(DistributedDataParallel):
    """Implements data parallelism at the module level for the DistributedDataParallel module.
    This container parallelizes the application of the given module by
    splitting the input across the specified devices by chunking in the
    batch dimension.
    In the forward pass, the module is replicated on each device,
    and each replica handles a portion of the input. During the backwards pass,
    gradients from each replica are summed into the original module.
    Note that the outputs are not gathered, please use compatible
    :class:`encoding.parallel.DataParallelCriterion`.
    The batch size should be larger than the number of GPUs used. It should
    also be an integer multiple of the number of GPUs so that each chunk is
    the same size (so that each GPU processes the same number of samples).
    Args:
        module: module to be parallelized
        device_ids: CUDA devices (default: all devices)
    Reference:
        Hang Zhang, Kristin Dana, Jianping Shi, Zhongyue Zhang, Xiaogang Wang, Ambrish Tyagi,
        Amit Agrawal. “Context Encoding for Semantic Segmentation.
        *The IEEE Conference on Computer Vision and Pattern Recognition (CVPR) 2018*
    Example::
        >>> net = encoding.nn.DistributedDataParallelModel(model, device_ids=[0, 1, 2])
        >>> y = net(x)
    """
    def gather(self, outputs, output_device):
        return outputs


class DataParallelModel(DataParallel):
    """Implements data parallelism at the module level.
    This container parallelizes the application of the given module by
    splitting the input across the specified devices by chunking in the
    batch dimension.
    In the forward pass, the module is replicated on each device,
    and each replica handles a portion of the input. During the backwards pass,
    gradients from each replica are summed into the original module.
    Note that the outputs are not gathered, please use compatible
    :class:`encoding.parallel.DataParallelCriterion`.
    The batch size should be larger than the number of GPUs used. It should
    also be an integer multiple of the number of GPUs so that each chunk is
    the same size (so that each GPU processes the same number of samples).
    Args:
        module: module to be parallelized
        device_ids: CUDA devices (default: all devices)
    Reference:
        Hang Zhang, Kristin Dana, Jianping Shi, Zhongyue Zhang, Xiaogang Wang, Ambrish Tyagi,
        Amit Agrawal. “Context Encoding for Semantic Segmentation.
        *The IEEE Conference on Computer Vision and Pattern Recognition (CVPR) 2018*
    Example::
        >>> net = encoding.nn.DataParallelModel(model, device_ids=[0, 1, 2])
        >>> y = net(x)
    """
    def gather(self, outputs, output_device):
        return outputs

    def replicate(self, module, device_ids):
        modules = super(DataParallelModel, self).replicate(module, device_ids)
        execute_replication_callbacks(modules)
        return modules


class DataParallelCriterion(DataParallel):
    """
    Calculate loss in multiple-GPUs, which balance the memory usage.
    The targets are splitted across the specified devices by chunking in
    the batch dimension. Please use together with :class:`encoding.parallel.DataParallelModel`.
    Reference:
        Hang Zhang, Kristin Dana, Jianping Shi, Zhongyue Zhang, Xiaogang Wang, Ambrish Tyagi,
        Amit Agrawal. “Context Encoding for Semantic Segmentation.
        *The IEEE Conference on Computer Vision and Pattern Recognition (CVPR) 2018*
    Example::
        >>> net = encoding.nn.DataParallelModel(model, device_ids=[0, 1, 2])
        >>> criterion = encoding.nn.DataParallelCriterion(criterion, device_ids=[0, 1, 2])
        >>> y = net(x)
        >>> loss = criterion(y, target)
    """
    def forward(self, inputs, *targets, **kwargs):
        # input should be already scatterd
        # scattering the targets instead
        if not self.device_ids:
            return self.module(inputs, *targets, **kwargs)
        targets, kwargs = self.scatter(targets, kwargs, self.device_ids)
        if len(self.device_ids) == 1:
            return self.module(inputs, *targets[0], **kwargs[0])
        replicas = self.replicate(self.module, self.device_ids[:len(inputs)])
        outputs = _criterion_parallel_apply(replicas, inputs, targets, kwargs)
        #return Reduce.apply(*outputs) / len(outputs)
        #return self.gather(outputs, self.output_device).mean()
        return self.gather(outputs, self.output_device)


def _criterion_parallel_apply(modules, inputs, targets, kwargs_tup=None, devices=None):
    assert len(modules) == len(inputs)
    assert len(targets) == len(inputs)
    if kwargs_tup:
        assert len(modules) == len(kwargs_tup)
    else:
        kwargs_tup = ({},) * len(modules)
    if devices is not None:
        assert len(modules) == len(devices)
    else:
        devices = [None] * len(modules)

    lock = threading.Lock()
    results = {}
    if torch_ver != "0.3":
        grad_enabled = torch.is_grad_enabled()

    def _worker(i, module, input, target, kwargs, device=None):
        if torch_ver != "0.3":
            torch.set_grad_enabled(grad_enabled)
        if device is None:
            device = get_a_var(input).get_device()
        try:
            with torch.cuda.device(device):
                # this also avoids accidental slicing of `input` if it is a Tensor
                if not isinstance(input, (list, tuple)):
                    input = (input,)
                if not isinstance(target, (list, tuple)):
                    target = (target,)
                output = module(*(input + target), **kwargs)
            with lock:
                results[i] = output
        except Exception as e:
            with lock:
                results[i] = e
            raise ValueError('Exception Detected')

    if len(modules) > 1:
        threads = [threading.Thread(target=_worker,
                                    args=(i, module, input, target,
                                          kwargs, device),)
                   for i, (module, input, target, kwargs, device) in
                   enumerate(zip(modules, inputs, targets, kwargs_tup, devices))]

        for thread in threads:
            thread.start()
        for thread in threads:
            thread.join()
    else:
        _worker(0, modules[0], inputs[0], kwargs_tup[0], devices[0])

    outputs = []
    for i in range(len(inputs)):
        output = results[i]
        if isinstance(output, Exception):
            raise output
        outputs.append(output)
    return outputs


###########################################################################
# Adapted from Synchronized-BatchNorm-PyTorch.
# https://github.com/vacancy/Synchronized-BatchNorm-PyTorch
#
class CallbackContext(object):
    pass


def execute_replication_callbacks(modules):
    """
    Execute an replication callback `__data_parallel_replicate__` on each module created
    by original replication.
    The callback will be invoked with arguments `__data_parallel_replicate__(ctx, copy_id)`
    Note that, as all modules are isomorphism, we assign each sub-module with a context
    (shared among multiple copies of this module on different devices).
    Through this context, different copies can share some information.
    We guarantee that the callback on the master copy (the first copy) will be called ahead
    of calling the callback of any slave copies.
    """
    master_copy = modules[0]
    nr_modules = len(list(master_copy.modules()))
    ctxs = [CallbackContext() for _ in range(nr_modules)]

    for i, module in enumerate(modules):
        for j, m in enumerate(module.modules()):
            if hasattr(m, '__data_parallel_replicate__'):
                m.__data_parallel_replicate__(ctxs[j], i)


def patch_replication_callback(data_parallel):
    """
    Monkey-patch an existing `DataParallel` object. Add the replication callback.
    Useful when you have customized `DataParallel` implementation.
    Examples:
        > sync_bn = SynchronizedBatchNorm1d(10, eps=1e-5, affine=False)
        > sync_bn = DataParallel(sync_bn, device_ids=[0, 1])
        > patch_replication_callback(sync_bn)
        # this is equivalent to
        > sync_bn = SynchronizedBatchNorm1d(10, eps=1e-5, affine=False)
        > sync_bn = DataParallelWithCallback(sync_bn, device_ids=[0, 1])
    """

    assert isinstance(data_parallel, DataParallel)

    old_replicate = data_parallel.replicate

    @functools.wraps(old_replicate)
    def new_replicate(module, device_ids):
        modules = old_replicate(module, device_ids)
        execute_replication_callbacks(modules)
        return modules

    data_parallel.replicate = new_replicate

# %%
# !pip install packaging==21.3
# Out:
# Collecting packaging==21.3
#   Using cached packaging-21.3-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in f:\users\bob2\anaconda3\envs\grnd\lib\site-packages (from packaging==21.3) (3.1.2)
# Using cached packaging-21.3-py3-none-any.whl (40 kB)
# Installing collected packages: packaging
#   Attempting uninstall: packaging
#     Found existing installation: packaging 22.0
#     Uninstalling packaging-22.0:
#       Successfully uninstalled packaging-22.0
# Successfully installed packaging-21.3

# %%
# !python run.py --offline --batch_size 1 --ext_type TokenLevelEncoder --window_type token --kernel_size 256 --stride 256
# Out:
# Number of available CUDA devices: 1
# Using CUDA device 0
# get_data test
#          3.4396 : Building dataset test from orignial text documents
#         58.0773 : Generating Batches
#         58.3021 : Finish Loading dataset test
#         58.3103 : There are 1027 batches in valid data
# 1 (1, 54, 1024) ['spotify:episode:74t5WREXUbhEKNI89CNSkL'] 2.1798017024993896
# 2 (1, 75, 1024) ['spotify:episode:5fG4VlWnWwzAt6mSs0H7lY'] 2.7420132160186768
# 3 (1, 54, 1024) ['spotify:episode:5hvOWPoB0j6HMrSVAMtJLV'] 3.1403274536132812
# 4 (1, 43, 1024) ['spotify:episode:7JG3lLnRoDdOxuqjf14ZkM'] 3.4496114253997803
# 5 (1, 44, 1024) ['spotify:episode:2WQ1GcC6J0k7qsO8Vvf2be'] 3.7607624530792236
# 6 (1, 53, 1024) ['spotify:episode:3kkhUQJ9DXYs6aSdDmPp2V'] 4.1623430252075195
# 7 (1, 46, 1024) ['spotify:episode:4fJ6Y6IpljKy8FT8DZHx1L'] 4.534748554229736
# 8 (1, 59, 1024) ['spotify:episode:5xBPWxqVCocdBgybmHjr5V'] 5.022202491760254
# 9 (1, 50, 1024) ['spotify:episode:0Sidld7sRx7bCpxEI9bdSs'] 5.452049016952515
# 10 (1, 25, 1024) ['spotify:episode:0X663c1I6j1cehJvy10WMm'] 5.65950608253479
# 11 (1, 46, 1024) ['spotify:episode:61a1JjZO27lGCvCwBaCkpC'] 6.079561471939087
# 12 (1, 19, 1024) ['spotify:episode:6jTICOEaZJrExbnvuFZh8e'] 6.239494323730469
# 13 (1, 54, 1024) ['spotify:episode:0goWRy1gwB23rQVy8ci7Wa'] 6.732851266860962
# 14 (1, 26, 1024) ['spotify:episode:0BSD8QYmd2mQ1V43uIrU4I'] 6.969452857971191
# 15 (1, 13, 1024) ['spotify:episode:5xH3cdpkxnJhQjPV22sxKC'] 7.090252161026001
# 16 (1, 32, 1024) ['spotify:episode:0YPvJfSEw0jacPB3IeT37d'] 7.381387710571289
# 17 (1, 43, 1024) ['spotify:episode:2BeLZJ6MuUpNMDCE0B9Oxx'] 7.779455661773682
# 18 (1, 41, 1024) ['spotify:episode:0hanwxxWNkOIhQ2WGVPgDZ'] 8.150154113769531
# 19 (1, 28, 1024) ['spotify:episode:0xO8sChswIL2Kafe4HEc2m'] 8.404391527175903
# 20 (1, 79, 1024) ['spotify:episode:2OmlLYu6eCJAgW70Dd4mNI'] 9.198986768722534
# 21 (1, 14, 1024) ['spotify:episode:4qUfA4SJE37KDe4UQ7theq'] 9.33207392692566
# 22 (1, 3, 1024) ['spotify:episode:6LhzGRUTkJ3jOp8uB2nXmh'] 9.365142107009888
# 23 (1, 39, 1024) ['spotify:episode:7jYX9RHORVq3n9dik62T1V'] 9.72946572303772
# 24 (1, 22, 1024) ['spotify:episode:5UgPhRu7ohxmIYVRpU7qmP'] 9.942634344100952
# 25 (1, 55, 1024) ['spotify:episode:4pwnJMycvw3pLhtzKoITZg'] 10.454204082489014
# 26 (1, 19, 1024) ['spotify:episode:5WeGGurhgoXNbWPsI50WpW'] 10.62929654121399
# 27 (1, 10, 1024) ['spotify:episode:01D58jn9qXZ01y8pRQX0KZ'] 10.719624042510986
# 28 (1, 6, 1024) ['spotify:episode:1gnpv26FFvIxpnwVbbRXv1'] 10.782240152359009
# 29 (1, 5, 1024) ['spotify:episode:2D8ox5Y4I9RREcvxqN85Sw'] 10.849129915237427
# 30 (1, 9, 1024) ['spotify:episode:3Cr6PDcEveTQv2LR7TeK9p'] 10.935353755950928
# 31 (1, 43, 1024) ['spotify:episode:5bXgUHNbzbHLzbatx4Qxwq'] 11.339346885681152
# 32 (1, 41, 1024) ['spotify:episode:6hA1uewG13trXQfpzjxoxc'] 11.714722633361816
# 33 (1, 5, 1024) ['spotify:episode:6FgJGwC3GFlWIMDRoFgcIA'] 11.763907194137573
# 34 (1, 9, 1024) ['spotify:episode:57Nzb9H2VRZgHcNFChwbBG'] 11.852265357971191
# 35 (1, 21, 1024) ['spotify:episode:63Mn0tilEbrdjpNETBFFyU'] 12.070680379867554
# 36 (1, 14, 1024) ['spotify:episode:1tN044BhlPjjiluZ7Wo7UL'] 12.205656290054321
# 37 (1, 11, 1024) ['spotify:episode:5mYAjoyjksszJLQmLkHjfD'] 12.329101800918579
# 38 (1, 40, 1024) ['spotify:episode:1yFB7vDET2XNWJfywuXr20'] 12.738872051239014
# 39 (1, 3, 1024) ['spotify:episode:4NYq8zSPPeej3rHQGOylj4'] 12.775444746017456
# 40 (1, 32, 1024) ['spotify:episode:1fs86N6FLUKW2e5NdX1dF1'] 13.079147815704346
# 41 (1, 20, 1024) ['spotify:episode:1iqN3P44yJmB4YdIwGmgmj'] 13.28572940826416
# 42 (1, 17, 1024) ['spotify:episode:1VqyL3ui763W5juwdtOl8u'] 13.535788774490356
# 43 (1, 41, 1024) ['spotify:episode:40cQ1OZKNp9XhUTHa92mdK'] 13.900808572769165
# 44 (1, 23, 1024) ['spotify:episode:0S1ejzvKzr6BJZVUkIGXpr'] 14.143434286117554
# 45 (1, 2, 1024) ['spotify:episode:1Mi90UjG91rm73qvHzcG0t'] 14.172585725784302
# 46 (1, 3, 1024) ['spotify:episode:61Ew1HhTy8t7W1chsUui5P'] 14.198961019515991
# 47 (1, 4, 1024) ['spotify:episode:6dJEEXH6MAG6o41BcrhRg9'] 14.253917455673218
# 48 (1, 8, 1024) ['spotify:episode:3TuC8HZp9VdXtxYMQkJI0m'] 14.34225344657898
# 49 (1, 13, 1024) ['spotify:episode:67v8V9SOXxivYQfAHSsc5f'] 14.489136695861816
# 50 (1, 11, 1024) ['spotify:episode:3SuGfoPpA0qhYAbgaubGag'] 14.621906042098999
# 51 (1, 19, 1024) ['spotify:episode:7xtTe8nQgZHvvRzZnaPDQm'] 14.809645652770996
# 52 (1, 10, 1024) ['spotify:episode:7EdzVT40JdUg2ksNrF8PPG'] 14.912081956863403
# 53 (1, 13, 1024) ['spotify:episode:6oDaSWhrZvuPTWJPo1v4AN'] 15.049163103103638
# 54 (1, 57, 1024) ['spotify:episode:5N35jBJdL0mgkJS582Ph8U'] 15.734469175338745
# 55 (1, 13, 1024) ['spotify:episode:7FzGkLbgKd2OTm4a4peLff'] 15.869764804840088
# 56 (1, 2, 1024) ['spotify:episode:0UN2333WN6uhH8OG3rqL0B'] 15.898724794387817
# 57 (1, 2, 1024) ['spotify:episode:5GF9sag5MsGgf4vJ7KeDgW'] 15.919740438461304
# 58 (1, 38, 1024) ['spotify:episode:5gZiIK2QRQp7Q8GqEO8yMN'] 16.304468154907227
# 59 (1, 32, 1024) ['spotify:episode:1eByVXjS1xk4NUnmVdSG2q'] 16.65809965133667
# 60 (1, 27, 1024) ['spotify:episode:1SdguXlFBsxMcYtdPyh0oH'] 16.966007947921753
# 61 (1, 72, 1024) ['spotify:episode:74uG6WCD6Ozv7vkvqy5bmy'] 17.87195587158203
# 62 (1, 30, 1024) ['spotify:episode:0zCllho8Bp9S9X8r6BGIzy'] 18.201213121414185
# 63 (1, 17, 1024) ['spotify:episode:65XzckmIKNN630iSTdhyLl'] 18.38354778289795
# 64 (1, 7, 1024) ['spotify:episode:5kz6Ox8TqDStNMYedf9ZYj'] 18.47326135635376
# 65 (1, 61, 1024) ['spotify:episode:3tzoElYoixtgMaTJ1FiZad'] 19.153385639190674
# 66 (1, 20, 1024) ['spotify:episode:4h0IrHrLcRKGSu5lMsA6aZ'] 19.351155996322632
# 67 (1, 58, 1024) ['spotify:episode:04Llj5QjDot46TEDGj7lbI'] 20.04840087890625
# 68 (1, 27, 1024) ['spotify:episode:4ijLcnLsOROn4ZQ98sIJ3C'] 20.316962480545044
# 69 (1, 32, 1024) ['spotify:episode:0op3gn49oYS727UmUk34pG'] 20.648682832717896
# 70 (1, 44, 1024) ['spotify:episode:0zRdLTXGRoy0tnwaa6JUJp'] 21.13225531578064
# 71 (1, 2, 1024) ['spotify:episode:3z5zWuMnniPKcTPymHRRXI'] 21.163654088974
# 72 (1, 56, 1024) ['spotify:episode:4binf19HlONLOyllpvCbiu'] 21.872652769088745
# 73 (1, 15, 1024) ['spotify:episode:4ZH14XkcgkqKt3kZd91e9e'] 22.080888986587524
# 74 (1, 31, 1024) ['spotify:episode:00yoUSA2yh7eAY8t45JM91'] 22.46276021003723
# 75 (1, 35, 1024) ['spotify:episode:4dYF6D4G0WG6dHG6KmY52Z'] 22.890594482421875
# 76 (1, 30, 1024) ['spotify:episode:4r1Y8TxG9I3eSykOoOPdK9'] 23.190081119537354
# 77 (1, 44, 1024) ['spotify:episode:3pd9Ak7rGhCbU4dBI9U54U'] 23.770429849624634
# 78 (1, 55, 1024) ['spotify:episode:4oFsHnI2XAVTF5DFVxXkUd'] 24.448283910751343
# 79 (1, 40, 1024) ['spotify:episode:2oc3ofJDxmI2nLlNYhJHvN'] 24.968026399612427
# 80 (1, 16, 1024) ['spotify:episode:7pXKuHWbih8qvwxdHDL6QH'] 25.155571699142456
# 81 (1, 21, 1024) ['spotify:episode:63VTIHMBAx5PT0UWAWsSR2'] 25.395033836364746
# 82 (1, 43, 1024) ['spotify:episode:4EjEDQ07dEN1aEohVLA9kM'] 25.965503931045532
# 83 (1, 59, 1024) ['spotify:episode:4fc9pHdOmLSpd1n4hPt8J1'] 26.737953186035156
# 84 (1, 50, 1024) ['spotify:episode:1bAKxMWwgxHIYaWiRSrxCa'] 27.338318824768066
# 85 (1, 15, 1024) ['spotify:episode:2bI4lMf13AufxzbyaH83vI'] 27.531363487243652
# 86 (1, 28, 1024) ['spotify:episode:6SMi2jM171MB6QjrYYWiX7'] 27.831098556518555
# 87 (1, 40, 1024) ['spotify:episode:19UIiUCEcxaKlJN9Ze4BMq'] 28.248422384262085
# 88 (1, 48, 1024) ['spotify:episode:4RqZcPw9ajffb2pNEbtoLf'] 28.738165616989136
# 89 (1, 18, 1024) ['spotify:episode:5eDxMMslKEKsRTeAoGxtR8'] 28.912754774093628
# 90 (1, 28, 1024) ['spotify:episode:6MaijKHa5MU0MsdS0yVZHE'] 29.19175934791565
# 91 (1, 58, 1024) ['spotify:episode:1EcBqy8tM3TYInm1k8Fdbm'] 29.81309723854065
# 92 (1, 12, 1024) ['spotify:episode:2bA3SdEDHSWpbpX4BL5TUf'] 29.942288875579834
# 93 (1, 18, 1024) ['spotify:episode:54u36GfxdJA6W7bUNa3dhp'] 30.12018346786499
# 94 (1, 10, 1024) ['spotify:episode:6HSy9G5DQ4hCSKF1Eup6vl'] 30.24790382385254
# 95 (1, 6, 1024) ['spotify:episode:3IopPCG19D4tcArUMWKWVo'] 30.31769061088562
# 96 (1, 26, 1024) ['spotify:episode:6rh4J52THn252yi7t11Yqf'] 30.584585666656494
# 97 (1, 8, 1024) ['spotify:episode:3IfmcM2rcWb82601pkPvCh'] 30.677958726882935
# 98 (1, 8, 1024) ['spotify:episode:5LJ33LdXWhqOu1KNad6D5q'] 30.76359248161316
# 99 (1, 56, 1024) ['spotify:episode:2vHZxpgRqhLb9kQtWtAyeD'] 31.384177684783936
# 100 (1, 10, 1024) ['spotify:episode:1AxFBio6NwwG0MAjdCK5gK'] 31.478789806365967
# 101 (1, 20, 1024) ['spotify:episode:0WRN8bvbvhuPkz8endKcQw'] 31.686169385910034
# 102 (1, 54, 1024) ['spotify:episode:3U33mRnDJcXywmBm1hahlL'] 32.33985686302185
# 103 (1, 32, 1024) ['spotify:episode:3MnIafaIOHo6zFKwH2cqFt'] 32.65293049812317
# 104 (1, 59, 1024) ['spotify:episode:66tGvgRWMed6a5NntU6aMO'] 33.21795344352722
# 105 (1, 23, 1024) ['spotify:episode:6vRLNVEQ4xqtMxnms3RZh3'] 33.44054579734802
# 106 (1, 2, 1024) ['spotify:episode:0zMtGhvoHebaXSN1aI0GZk'] 33.47379183769226
# 107 (1, 53, 1024) ['spotify:episode:4Au2TYKBkgjoKI1NSAbJ2X'] 34.144855976104736
# 108 (1, 48, 1024) ['spotify:episode:7LPJwnIf5dt0DNO2Ub21Zv'] 34.73017644882202
# 109 (1, 2, 1024) ['spotify:episode:6ZZPr8CRFerqbJbm3SV8QD'] 34.767534494400024
# 110 (1, 56, 1024) ['spotify:episode:1A4cHtP3wIVQutpCgS7kd7'] 35.48773002624512
# 111 (1, 43, 1024) ['spotify:episode:0M3KRN3z6vnQ0ZxtaCofjy'] 36.038225412368774
# 112 (1, 44, 1024) ['spotify:episode:1ApB11TSx0Er4nGpobujUN'] 36.56972861289978
# 113 (1, 18, 1024) ['spotify:episode:4EXzSCiNj5DpQVavxZOW5Y'] 36.74725842475891
# 114 (1, 55, 1024) ['spotify:episode:1STy1PKd5MLtccOTCcuKNB'] 37.410009145736694
# 115 (1, 44, 1024) ['spotify:episode:0aAUYpI63EuJu1oZuwLKQ1'] 37.959232568740845
# 116 (1, 82, 1024) ['spotify:episode:1IdIzNXBCtUTHLHCtq0z8F'] 38.89707851409912
# 117 (1, 2, 1024) ['spotify:episode:0GhKpVQxZbFpsKCUpSXiEl'] 38.92633891105652
# 118 (1, 2, 1024) ['spotify:episode:0gyArGeoo8PxuDEztd4Zi8'] 38.95207142829895
# 119 (1, 1, 1024) ['spotify:episode:29vKVaojQUSycOz9771DRV'] 38.97782874107361
# 120 (1, 2, 1024) ['spotify:episode:7z1HcpGoE73k76n2mStdb1'] 38.9984929561615
# 121 (1, 17, 1024) ['spotify:episode:19dI2U8hcafCQyNx7GBTwp'] 39.19347548484802
# 122 (1, 45, 1024) ['spotify:episode:0P659hEswmA4xGbk441q0a'] 39.71671390533447
# 123 (1, 55, 1024) ['spotify:episode:1E23TJE5PZuN8hFIbiOkie'] 40.315523862838745
# 124 (1, 70, 1024) ['spotify:episode:18lig7ccnoUaQ5roIneR6v'] 41.093082427978516
# 125 (1, 59, 1024) ['spotify:episode:1RsgjqOAPQA3nisyjNhRXR'] 41.82932710647583
# 126 (1, 39, 1024) ['spotify:episode:3Tw5nrzBqIUdMGT5QKzrn1'] 42.229265451431274
# 127 (1, 48, 1024) ['spotify:episode:741QNkcc4nclxxDmCfNPfd'] 42.76520824432373
# 128 (1, 53, 1024) ['spotify:episode:1CvO5knL0cCgK2FxBLTnQn'] 43.30158877372742
# 129 (1, 42, 1024) ['spotify:episode:65COV7d8fqV18YMr9msAjy'] 43.817291498184204
# 130 (1, 10, 1024) ['spotify:episode:6umHHB6iqzHLXLypmVSSsp'] 43.913349628448486
# 131 (1, 39, 1024) ['spotify:episode:3L9UtDN1bPoKcEGU1BmCeT'] 44.36327767372131
# 132 (1, 67, 1024) ['spotify:episode:0UoTnPStSJhNpGGrEqomO7'] 45.16955232620239
# 133 (1, 40, 1024) ['spotify:episode:61qD2Hx7Jk0EXW2JdjWsbF'] 45.56635904312134
# 134 (1, 50, 1024) ['spotify:episode:7vfnLgfVgyoKW1fx2ABk3t'] 46.13789772987366
# 135 (1, 21, 1024) ['spotify:episode:5KmQJxIx9cbsbR4EFcCNTU'] 46.369256019592285
# 136 (1, 24, 1024) ['spotify:episode:0m0vtDTApnpVY19ldI5TSO'] 46.62259769439697
# 137 (1, 57, 1024) ['spotify:episode:4wre0ib032sCXyY1AqEnN8'] 47.33471632003784
# 138 (1, 56, 1024) ['spotify:episode:6j0wE9WfFtD2rw8qBjIOD3'] 47.94733643531799
# 139 (1, 8, 1024) ['spotify:episode:3IIkG9brkIxghJr4j2D9S0'] 48.03631854057312
# 140 (1, 5, 1024) ['spotify:episode:1UxCFPxYRwTLwqKNbmKkRh'] 48.090943813323975
# 141 (1, 6, 1024) ['spotify:episode:1ViBONBXnAVV5K5cmSnPID'] 48.17655897140503
# 142 (1, 23, 1024) ['spotify:episode:07y0yNc4rF8JOVDEAX7zT2'] 48.435054540634155
# 143 (1, 31, 1024) ['spotify:episode:1Gs0FfKfblOH4nFbIi0yIL'] 48.800833225250244
# 144 (1, 59, 1024) ['spotify:episode:4luRcjjsoQ0JZQeGj3Q9sZ'] 49.640538692474365
# 145 (1, 70, 1024) ['spotify:episode:7rFkj9L0485jt8RQUJYZFw'] 50.71948981285095
# 146 (1, 28, 1024) ['spotify:episode:1nuuDAGWRw5jzRFpZ1KsTB'] 51.111122846603394
# 147 (1, 46, 1024) ['spotify:episode:5nyTcEX92EbnzM2gKsd6Z0'] 51.74080991744995
# 148 (1, 14, 1024) ['spotify:episode:1BssSMXV3q1wibvkDw9zym'] 51.884172677993774
# 149 (1, 24, 1024) ['spotify:episode:1JdBQNxOOXManwRuQkCMdl'] 52.17601227760315
# 150 (1, 67, 1024) ['spotify:episode:4cVw0lqjRFJREdtC5SbGhB'] 52.84246611595154
# 151 (1, 15, 1024) ['spotify:episode:2r61XEL7n8RHgo3fJ9nf5W'] 52.97796583175659
# 152 (1, 6, 1024) ['spotify:episode:4nrHgM46qx9b8kPRwQ4oxS'] 53.046340465545654
# 153 (1, 6, 1024) ['spotify:episode:5RVYMzhywXmR1zgdMBVLdo'] 53.112871408462524
# 154 (1, 5, 1024) ['spotify:episode:62zz0iXBw9hdJBgmdg7b1o'] 53.16315507888794
# 155 (1, 68, 1024) ['spotify:episode:5keIVZjAOxUYtOCCcrPykx'] 53.99612617492676
# 156 (1, 24, 1024) ['spotify:episode:3U0HWCXbEwpx0FqKM1LGeF'] 54.2427864074707
# 157 (1, 27, 1024) ['spotify:episode:3tuDrorZwfSjxV6q8D8bWV'] 54.52963876724243
# 158 (1, 42, 1024) ['spotify:episode:3aG5oFNe8YXUAjW70KImUO'] 55.01793336868286
# 159 (1, 26, 1024) ['spotify:episode:3xwXYI4A79TXcrFmMwRGV1'] 55.35193943977356
# 160 (1, 32, 1024) ['spotify:episode:3z9Kkk9LNEH2TGkilqcPFr'] 55.67849636077881
# 161 (1, 63, 1024) ['spotify:episode:7AkSwKS9QXaeVvKqMDoYZz'] 56.569947242736816
# 162 (1, 68, 1024) ['spotify:episode:0oypCK0pVtH8tjfnl4upld'] 57.34634256362915
# 163 (1, 7, 1024) ['spotify:episode:2iHQ2Podbz94B7T9g1xAJj'] 57.426435232162476
# 164 (1, 51, 1024) ['spotify:episode:5Nw2YdtgBpeNVu930Dfm82'] 57.955533504486084
# 165 (1, 41, 1024) ['spotify:episode:4VP2BLxOIpKovao5pj7Ozh'] 58.3972647190094
# 166 (1, 51, 1024) ['spotify:episode:2JdJDvmLZmvPs6utmjPf7w'] 58.9060115814209
# 167 (1, 12, 1024) ['spotify:episode:30WDFMlfnfnxGLTT2uyAHt'] 59.03317737579346
# 168 (1, 20, 1024) ['spotify:episode:1j8xGvO6QhVEwJTBsnBexV'] 59.23693823814392
# 169 (1, 10, 1024) ['spotify:episode:6VIlDWxH6CVNFTFEV5ffLU'] 59.3459210395813
# 170 (1, 8, 1024) ['spotify:episode:1LUAwERMFZTzF1mLwYlgWL'] 59.432286500930786
# 171 (1, 4, 1024) ['spotify:episode:6bOBHGBiUwcNXGVX1lHNJJ'] 59.48300623893738
# 172 (1, 5, 1024) ['spotify:episode:7Gyz6XJOSfpVyTyuiwzDFo'] 59.53605842590332
# 173 (1, 21, 1024) ['spotify:episode:5SNOrSlsEQAWel2fRqAzgd'] 59.75191378593445
# 174 (1, 10, 1024) ['spotify:episode:2Yqc6JVpmh4x6ttfyGJmH0'] 59.85323214530945
# 175 (1, 8, 1024) ['spotify:episode:3WCDMrTVPMlsCCm2leHeKo'] 59.946784257888794
# 176 (1, 1, 1024) ['spotify:episode:3wmaIscdYrhlfwLdBIeJgc'] 59.96678853034973
# 177 (1, 8, 1024) ['spotify:episode:4771LyN83ZlgeFY41F0fUF'] 60.07038116455078
# 178 (1, 2, 1024) ['spotify:episode:3poJW4PDsdAdjq0Qc3Nqdc'] 60.098419189453125
# 179 (1, 18, 1024) ['spotify:episode:4Qw0HaArDmbZ1S2Y5Xz9Wb'] 60.34590554237366
# 180 (1, 17, 1024) ['spotify:episode:5HgghCc98bo2LiXzKy0F27'] 60.533453941345215
# 181 (1, 13, 1024) ['spotify:episode:4rPfjPdCOsE3yoIlkXi0OR'] 60.67373251914978
# 182 (1, 60, 1024) ['spotify:episode:3jw1ii8rxiNQqSY3UCTZEB'] 61.52444934844971
# 183 (1, 14, 1024) ['spotify:episode:0AT7TC6SCHBy6Ov8rRYqhh'] 61.66841125488281
# 184 (1, 16, 1024) ['spotify:episode:1023jGFb5RbOfcDuVUZyAc'] 61.8493332862854
# 185 (1, 19, 1024) ['spotify:episode:2vxeUuRU2vpCWhs0VVGJ3L'] 62.07114052772522
# 186 (1, 42, 1024) ['spotify:episode:0CSAvjHT7I3y3m7xYnWsvF'] 62.50977110862732
# 187 (1, 2, 1024) ['spotify:episode:0pKBbRxj9B38jXPSrcLlQN'] 62.536285161972046
# 188 (1, 9, 1024) ['spotify:episode:5g32LXEa0avWYfhOkukFkW'] 62.62529492378235
# 189 (1, 15, 1024) ['spotify:episode:0mJiSWZlk7e9gfCfnfCSoO'] 62.76394557952881
# 190 (1, 7, 1024) ['spotify:episode:0YPSB1d04Y7IQSsDLaLMjV'] 62.846702575683594
# 191 (1, 6, 1024) ['spotify:episode:6Wev5Q6hBdjOlsvJz5soql'] 62.91598320007324
# 192 (1, 6, 1024) ['spotify:episode:00SE6vEbN1PU6OFV9anG5i'] 62.98577356338501
# 193 (1, 53, 1024) ['spotify:episode:1uCTeiPEQgz2S6HdK7GVcx'] 63.61779808998108
# 194 (1, 53, 1024) ['spotify:episode:3YXRP2g5re7trFu5qRt0UF'] 64.25913214683533
# 195 (1, 22, 1024) ['spotify:episode:78ADFPnLWm6TsbxiUBjqEf'] 64.52843832969666
# 196 (1, 46, 1024) ['spotify:episode:6Jbvjbkq0U8Yi0FDlmFsxW'] 65.06798553466797
# 197 (1, 3, 1024) ['spotify:episode:1CeIpex7vxtvpmuHKtJzVz'] 65.11145281791687
# 198 (1, 2, 1024) ['spotify:episode:1Gcwzel68ribYC6kga7Eib'] 65.142906665802
# 199 (1, 8, 1024) ['spotify:episode:1jGjgYq3CLeFodbYnVcZeI'] 65.2405846118927
# 200 (1, 21, 1024) ['spotify:episode:4FCEDTngcC5R8G46Dd2Hhb'] 65.52860260009766
# 201 (1, 27, 1024) ['spotify:episode:0Ot4MuWV35ik4whp0ElQPo'] 65.83115363121033
# 202 (1, 43, 1024) ['spotify:episode:6qzBY3QlFYDFeoVOa5qTZ3'] 66.35598182678223
# 203 (1, 34, 1024) ['spotify:episode:5Rz9ej1R4inkurB9kAFmog'] 66.7172019481659
# 204 (1, 19, 1024) ['spotify:episode:2GvXwQH473RcY6MZfIZS5g'] 66.91563940048218
# 205 (1, 35, 1024) ['spotify:episode:2jvWqUD1asYvFsDAFsozkZ'] 67.33556199073792
# 206 (1, 19, 1024) ['spotify:episode:3nISIwPM7QihFPXbmLwGbD'] 67.55888509750366
# 207 (1, 48, 1024) ['spotify:episode:1lL6ZiffhbQZugtQgJmjeU'] 68.17130374908447
# 208 (1, 37, 1024) ['spotify:episode:1kjFvAiMfam1WoY2FFh95F'] 68.68542885780334
# 209 (1, 2, 1024) ['spotify:episode:6gKng0Ky1G2t3RogjU0BJu'] 68.71794557571411
# 210 (1, 36, 1024) ['spotify:episode:0Q99uc7PzbCUV8mgGIv0jA'] 69.15548419952393
# 211 (1, 15, 1024) ['spotify:episode:6kZ5r1mOO7kacj4hMp2u7O'] 69.32158184051514
# 212 (1, 22, 1024) ['spotify:episode:1t6aRpc7jv67gy92cVC7QS'] 69.58545899391174
# 213 (1, 17, 1024) ['spotify:episode:57jIOwpJBbaAKtnBb4OTWv'] 69.78503918647766
# 214 (1, 18, 1024) ['spotify:episode:5kurfyBmPZnOTMvmGVOVqS'] 69.98331499099731
# 215 (1, 49, 1024) ['spotify:episode:5qFRI0Ijls3Y7dQhreMfF1'] 70.63733458518982
# 216 (1, 23, 1024) ['spotify:episode:1wHRMsWVurmo56xd1AcSfe'] 70.9363796710968
# 217 (1, 10, 1024) ['spotify:episode:5Sjodl6tm5IqGU1IkzLacv'] 71.04516673088074
# 218 (1, 1, 1024) ['spotify:episode:38EoTOCXvcvpfbs9huAHiY'] 71.06553673744202
# 219 (1, 48, 1024) ['spotify:episode:07PYTGM4XiVlHhySx6hu1O'] 71.71658682823181
# 220 (1, 33, 1024) ['spotify:episode:62b7BBsEREb5xR90kbdJyU'] 72.08753895759583
# 221 (1, 51, 1024) ['spotify:episode:3ccPyGYCwlJJFobAvVNAHH'] 72.80510878562927
# 222 (1, 2, 1024) ['spotify:episode:3ZwGFq4cJyhrr7XeMPWAgL'] 72.83644700050354
# 223 (1, 43, 1024) ['spotify:episode:2LFJJhuPvjxhNLblmUaD2T'] 73.34539747238159
# 224 (1, 44, 1024) ['spotify:episode:40dECDdVVUcaV5Pq5Xlmye'] 73.82094073295593
# 225 (1, 11, 1024) ['spotify:episode:2Qn3ydT5r8YAmUrrXfomPg'] 73.945068359375
# 226 (1, 9, 1024) ['spotify:episode:4uJVL4hkW5sWPkYw4eol2F'] 74.03844785690308
# 227 (1, 13, 1024) ['spotify:episode:0ZRT4JQsFUEgUtTCW5Prvp'] 74.1851863861084
# 228 (1, 25, 1024) ['spotify:episode:4gaZmHUgWeaLy5ipNM3k4k'] 74.45264649391174
# 229 (1, 62, 1024) ['spotify:episode:3uXxGkvtfq74gZ3Uh4KiZx'] 75.16527462005615
# 230 (1, 24, 1024) ['spotify:episode:6UIvhzbWDYNRbd9PUfbto6'] 75.41764283180237
# 231 (1, 24, 1024) ['spotify:episode:6ro7quiJoa2fehJyNH3BRK'] 75.64761447906494
# 232 (1, 58, 1024) ['spotify:episode:0yGU9kyu15LePIpZXBfWA4'] 76.3552610874176
# 233 (1, 38, 1024) ['spotify:episode:4qfvLLcPSPbNDfTvnzDbv3'] 76.77941393852234
# 234 (1, 53, 1024) ['spotify:episode:1GOXInXdJrluLuLywx5NzP'] 77.35046291351318
# 235 (1, 58, 1024) ['spotify:episode:54L0QnebCHP3yrLoZVvT1I'] 77.99131178855896
# 236 (1, 23, 1024) ['spotify:episode:3wF2WxFD1Z9h6o01vnvs9q'] 78.23146462440491
# 237 (1, 46, 1024) ['spotify:episode:5Z454HXp7OOS4Rmt4RxuUQ'] 78.78402161598206
# 238 (1, 40, 1024) ['spotify:episode:3PwQkJhXUYzhu5xFRsEfEW'] 79.18581080436707
# 239 (1, 55, 1024) ['spotify:episode:2IzmhvYWT8iFnnys9PGrqe'] 79.70747876167297
# 240 (1, 61, 1024) ['spotify:episode:4i4UjhaaxuPotREqvCHPTR'] 80.36208868026733
# 241 (1, 24, 1024) ['spotify:episode:3ZWwdy2ACjZyZYcGgzOBxJ'] 80.59723210334778
# 242 (1, 55, 1024) ['spotify:episode:4kxFE88HyIkC1OsYCBGygB'] 81.22318291664124
# 243 (1, 21, 1024) ['spotify:episode:7xZNiHvpRZjl48Kr4GGRmF'] 81.43938207626343
# 244 (1, 10, 1024) ['spotify:episode:7uxCLFImRajqyHnlSKClCY'] 81.5328471660614
# 245 (1, 3, 1024) ['spotify:episode:6tAGRzQ2MK1N6nQoGTrX7c'] 81.57450366020203
# 246 (1, 73, 1024) ['spotify:episode:6cZTRnMg7cFeQcGoEvrpyB'] 82.4197130203247
# 247 (1, 45, 1024) ['spotify:episode:3eyWXfQ0lqsuDEe3SoiG1U'] 82.92829513549805
# 248 (1, 54, 1024) ['spotify:episode:0VDOpOZ8H0WLEy38sveMC4'] 83.55662846565247
# 249 (1, 2, 1024) ['spotify:episode:3vaqb9E0J8466F8J4UeDyE'] 83.58856320381165
# 250 (1, 3, 1024) ['spotify:episode:77j4J39C1m3LliGb0QqiMq'] 83.62725710868835
# 251 (1, 15, 1024) ['spotify:episode:0d2XEvk44IImTQKQM7fA0b'] 83.79264569282532
# 252 (1, 54, 1024) ['spotify:episode:6iuCEMkoHrH88ShBtZPtv3'] 84.50464129447937
# 253 (1, 37, 1024) ['spotify:episode:4lY18jNIVU9TcK0vQF5pbw'] 85.0033028125763
# 254 (1, 24, 1024) ['spotify:episode:5O6XZDo0aMzYq65210MBW5'] 85.30247759819031
# 255 (1, 41, 1024) ['spotify:episode:5TBGa9P2t85xYoCwY4Kg4L'] 85.78757929801941
# 256 (1, 34, 1024) ['spotify:episode:0m6KncX7KaCn3GkzQWtQfR'] 86.22160387039185
# 257 (1, 10, 1024) ['spotify:episode:6jXmrYyOmLNFL1g4n7ttLR'] 86.33904480934143
# 258 (1, 18, 1024) ['spotify:episode:1EPOaWpjdUB7lB589jjTx3'] 86.53730630874634
# 259 (1, 16, 1024) ['spotify:episode:5s5eoB48WmmAz3MFRk1IwV'] 86.767324924469
# 260 (1, 2, 1024) ['spotify:episode:0NJmaKcBPTiD5jIU40nFl4'] 86.79886674880981
# 261 (1, 3, 1024) ['spotify:episode:1TicQO3vAuYoPoS3XZeL6y'] 86.84402441978455
# 262 (1, 2, 1024) ['spotify:episode:25Vg76v8xDHeVq20caFUOr'] 86.87202835083008
# 263 (1, 2, 1024) ['spotify:episode:3SxE188dmuDZeTLiZ1NbFB'] 86.90225648880005
# 264 (1, 2, 1024) ['spotify:episode:3VC6zWWapVYCXanUeVtnnV'] 86.93426132202148
# 265 (1, 2, 1024) ['spotify:episode:3gqwRApB8dGhCbZAaRG4C1'] 86.96454930305481
# 266 (1, 2, 1024) ['spotify:episode:3kq7f86T2C6hrsYGU1YGhv'] 86.99695014953613
# 267 (1, 2, 1024) ['spotify:episode:3xNSneHkYqNyGDVgz5NKAl'] 87.02758932113647
# 268 (1, 2, 1024) ['spotify:episode:5a0dxl6w7wh5SGAbNpxhu4'] 87.05801916122437
# 269 (1, 2, 1024) ['spotify:episode:5zlM5rEhKnLt2n8rLvaSjk'] 87.090012550354
# 270 (1, 2, 1024) ['spotify:episode:6iiXb9jtiFQZCkX8PWiENL'] 87.12466406822205
# 271 (1, 2, 1024) ['spotify:episode:6rFE76cRZzwyz6xbiKLOvS'] 87.1566641330719
# 272 (1, 2, 1024) ['spotify:episode:6xLwW7EE4j0Mtk0kqs6ksl'] 87.18978977203369
# 273 (1, 2, 1024) ['spotify:episode:77M40y0Jm3ijFVeFf9cTEo'] 87.21782398223877
# 274 (1, 13, 1024) ['spotify:episode:1f6O4AbRyoD1OBzCCxhvHs'] 87.39239358901978
# 275 (1, 11, 1024) ['spotify:episode:1nu9U0Go32SUnkX5tdyiif'] 87.54831457138062
# 276 (1, 38, 1024) ['spotify:episode:2Mvvc1uSeeSkYOceWdYJbH'] 87.99633932113647
# 277 (1, 36, 1024) ['spotify:episode:5BwvPnQEk47FwCovs3pTLa'] 88.41428565979004
# 278 (1, 15, 1024) ['spotify:episode:1EwZ9ewnlXBQ3jH5ImlY3o'] 88.5644428730011
# 279 (1, 33, 1024) ['spotify:episode:6dUWcZFmMYSOPfDnaUIRHN'] 88.94724082946777
# 280 (1, 37, 1024) ['spotify:episode:2ZXgyKhQTtNbW0FR27AJFx'] 89.42497372627258
# 281 (1, 1, 1024) ['spotify:episode:6bmmcheEbj4Joxlq0Aa0u8'] 89.44495940208435
# 282 (1, 46, 1024) ['spotify:episode:20sozwCsw9pF9jb7ZVLDQO'] 90.01765942573547
# 283 (1, 63, 1024) ['spotify:episode:18RrfdH3hNjmB7QNR6OW2Q'] 90.79515337944031
# 284 (1, 35, 1024) ['spotify:episode:6P7EDq65iYGaSqYAhF0pau'] 91.20186233520508
# 285 (1, 19, 1024) ['spotify:episode:1dLHj9TDQMJwcR7NaJXNSe'] 91.38862586021423
# 286 (1, 18, 1024) ['spotify:episode:2lDhCSrdibSvo0Fuqd5Qz4'] 91.58501052856445
# 287 (1, 33, 1024) ['spotify:episode:1lp4wus6epwsnJ0OOLnb9V'] 91.96713542938232
# 288 (1, 39, 1024) ['spotify:episode:4eAJ4M8XgOxmGnJ2OTm1Zz'] 92.3982515335083
# 289 (1, 54, 1024) ['spotify:episode:7xOqb4P4BgTS241rOKWK3S'] 93.02730989456177
# 290 (1, 16, 1024) ['spotify:episode:4AirccIvUKYUufTRssOcgF'] 93.21775317192078
# 291 (1, 21, 1024) ['spotify:episode:4PzR1hMJTVrAXTvjhQ3iiQ'] 93.4362804889679
# 292 (1, 61, 1024) ['spotify:episode:0KXemB6zS74h3EYtenrU88'] 94.19597792625427
# 293 (1, 25, 1024) ['spotify:episode:7xDULonmcp2zK8EArJeE9Q'] 94.47175979614258
# 294 (1, 58, 1024) ['spotify:episode:00v0W2K3d8o68maX79QK2v'] 95.26955008506775
# 295 (1, 42, 1024) ['spotify:episode:2YhkeuIWznFXfwPIPjNpIs'] 95.82795262336731
# 296 (1, 7, 1024) ['spotify:episode:412MQ05nzDPeMOgXkULk8X'] 95.93343234062195
# 297 (1, 41, 1024) ['spotify:episode:22czpn4H5CzDYdLeIwGhgx'] 96.43482422828674
# 298 (1, 1, 1024) ['spotify:episode:4nwretW7h3lvVSHvPwIlHN'] 96.45387077331543
# 299 (1, 65, 1024) ['spotify:episode:4UDyrkdN2UXKz5skVrhYLt'] 97.35835671424866
# 300 (1, 54, 1024) ['spotify:episode:4DCggxggCqqnNwGwte123k'] 98.0310709476471
# 301 (1, 46, 1024) ['spotify:episode:64NnNm0GNA6bCvgExCiQS1'] 98.52945852279663
# 302 (1, 9, 1024) ['spotify:episode:0LZYTUUrbMB5wP7G9XkyG9'] 98.61975574493408
# 303 (1, 8, 1024) ['spotify:episode:22y7fCEJcla0WOdNwzPSZQ'] 98.7107515335083
# 304 (1, 8, 1024) ['spotify:episode:2RGzsuxFulWk9k3bvh1wrx'] 98.79533171653748
# 305 (1, 10, 1024) ['spotify:episode:6Go5xcf661AKDP9mCu9YOT'] 98.8909752368927
# 306 (1, 8, 1024) ['spotify:episode:7Bcdj9uBKoLBlLxf4RrQxo'] 98.97745871543884
# 307 (1, 9, 1024) ['spotify:episode:7HLrdkrb1vNHawTPSkPoX0'] 99.07810139656067
# 308 (1, 9, 1024) ['spotify:episode:7hTd80vEedV9yWep6nsW3D'] 99.17297029495239
# 309 (1, 35, 1024) ['spotify:episode:7glTFtfqlbsGBT9ED2ceC9'] 99.57632064819336
# 310 (1, 3, 1024) ['spotify:episode:6kkiT5J8sNm2ngOriAhjQA'] 99.61625504493713
# 311 (1, 48, 1024) ['spotify:episode:3ITngE4g63580uYRhbtVc0'] 100.13841319084167
# 312 (1, 31, 1024) ['spotify:episode:1xJ3cZUIQyVZo0v88eJrhx'] 100.50144863128662
# 313 (1, 4, 1024) ['spotify:episode:1opKYBaYpchAbq8zBSOnQQ'] 100.54949951171875
# 314 (1, 4, 1024) ['spotify:episode:6qU70I7BJ4nYMgX56r5nLr'] 100.5997748374939
# 315 (1, 5, 1024) ['spotify:episode:1UMDHZXjPuxIVnYyAS76fn'] 100.67218375205994
# 316 (1, 32, 1024) ['spotify:episode:1wkDtHEZAjbZ3J3JvF9glp'] 101.07730793952942
# 317 (1, 24, 1024) ['spotify:episode:2RoLspr2PQTki51sfMhd20'] 101.36180233955383
# 318 (1, 21, 1024) ['spotify:episode:5MoLR17giFknmCVM7yfjFL'] 101.58073616027832
# 319 (1, 12, 1024) ['spotify:episode:79VCM6WVZyTpXmvUoBskcW'] 101.72197914123535
# 320 (1, 25, 1024) ['spotify:episode:4mIDH8PmX4EzRQS9qotLZK'] 101.96610236167908
# 321 (1, 4, 1024) ['spotify:episode:5D5PIp1SQGtTtSNIcHwtaC'] 102.01227450370789
# 322 (1, 42, 1024) ['spotify:episode:02Xspg91AD2xkKkhZq8JbW'] 102.49622750282288
# 323 (1, 23, 1024) ['spotify:episode:7pV9VUTv728HQYvH3Rz3pl'] 102.72114062309265
# 324 (1, 11, 1024) ['spotify:episode:1G02hUDmyMFk1aKts60uPC'] 102.8448052406311
# 325 (1, 28, 1024) ['spotify:episode:6ciBUflvfzpBg1vIRvyMUu'] 103.12428665161133
# 326 (1, 52, 1024) ['spotify:episode:60BOydXSgzIAULasuytwoE'] 103.69404816627502
# 327 (1, 21, 1024) ['spotify:episode:1bQRezGLZvyQ0LZIecFQcu'] 103.93281316757202
# 328 (1, 30, 1024) ['spotify:episode:6nJ9hZUOsSBC2O0LXESQZJ'] 104.22484683990479
# 329 (1, 90, 1024) ['spotify:episode:1HmN1BDPrSiIdYEWTX84xz'] 105.37342500686646
# 330 (1, 49, 1024) ['spotify:episode:3PNi9kttzxBKam2wLTqUns'] 105.96537065505981
# 331 (1, 37, 1024) ['spotify:episode:70rOGx6FdOyDfsRne4nC8K'] 106.37687540054321
# 332 (1, 22, 1024) ['spotify:episode:4tVNpWFLK9F8vdJztRQAfS'] 106.59923720359802
# 333 (1, 48, 1024) ['spotify:episode:0FD7VzZqVHegXB4IjjHzxU'] 107.0825400352478
# 334 (1, 16, 1024) ['spotify:episode:2wcWNsVoP4vH9rImLn95De'] 107.25961804389954
# 335 (1, 42, 1024) ['spotify:episode:4Yfx0d7pPnULlu9xca7Cv6'] 107.74221467971802
# 336 (1, 46, 1024) ['spotify:episode:2laK2KWhOwEHHZma4o2mmp'] 108.23526883125305
# 337 (1, 2, 1024) ['spotify:episode:1mXRsVMHiDyFnIToevJrth'] 108.26330757141113
# 338 (1, 26, 1024) ['spotify:episode:3nxaDA81GayEGf5EHMkBix'] 108.58655524253845
# 339 (1, 33, 1024) ['spotify:episode:0H2ddnzaPo7bzLehITRbPh'] 108.9754683971405
# 340 (1, 33, 1024) ['spotify:episode:16s5bsrcE0ynNKWLtsKtxN'] 109.37265014648438
# 341 (1, 46, 1024) ['spotify:episode:28KX5G6NggK1flHskQl9Hx'] 109.92633509635925
# 342 (1, 56, 1024) ['spotify:episode:0YNXWc7r9Udpdc43wa7buG'] 110.5112133026123
# 343 (1, 55, 1024) ['spotify:episode:6JZfnNHguNXeefH6NsrgJ4'] 111.13329815864563
# 344 (1, 5, 1024) ['spotify:episode:2GvU6pylpnxCQhGRYEHLGQ'] 111.18379139900208
# 345 (1, 11, 1024) ['spotify:episode:0xy3q1Kxd3N10NI1dBDkKz'] 111.3127863407135
# 346 (1, 15, 1024) ['spotify:episode:5ycbjj3B4EN8Z8nRB50ytA'] 111.4639892578125
# 347 (1, 12, 1024) ['spotify:episode:5p4YAPI2Y3aivCRZt2f950'] 111.62125158309937
# 348 (1, 4, 1024) ['spotify:episode:2kyirVCVfkv05DQF6K9ZnQ'] 111.67984342575073
# 349 (1, 29, 1024) ['spotify:episode:2zXOWTIQl8hpOrR6hnRydo'] 112.05143570899963
# 350 (1, 20, 1024) ['spotify:episode:080Fqmt2J3kjK5MVyH5qsN'] 112.30486488342285
# 351 (1, 7, 1024) ['spotify:episode:0ouOaap6g2IK0UVgG4vtRi'] 112.39161705970764
# 352 (1, 37, 1024) ['spotify:episode:0PZRAzyEeJeZNgyp1dXB9s'] 112.84850931167603
# 353 (1, 30, 1024) ['spotify:episode:4xDdFsrqEOz6oQFWq1P5AW'] 113.21264004707336
# 354 (1, 25, 1024) ['spotify:episode:38ujs4H05aAJSaIu5DNXMA'] 113.49566555023193
# 355 (1, 17, 1024) ['spotify:episode:5wCaqlb9qtBsDjj2WeY2iX'] 113.68300557136536
# 356 (1, 7, 1024) ['spotify:episode:2uH1NtNsmwrCPaEVKCy0zG'] 113.77238464355469
# 357 (1, 48, 1024) ['spotify:episode:7j9V5XkPLxnujBkSk2iWKv'] 114.38257050514221
# 358 (1, 35, 1024) ['spotify:episode:7Fa3UOJcQ7xgRAPPoBbQj2'] 114.82132053375244
# 359 (1, 42, 1024) ['spotify:episode:3m4kESfM7FFqOxh9hs48rz'] 115.3920373916626
# 360 (1, 18, 1024) ['spotify:episode:6GkMo84lpcM4pwA46A25R6'] 115.62691926956177
# 361 (1, 28, 1024) ['spotify:episode:0a4PoYzizK9RPlI7BfBoif'] 115.98740363121033
# 362 (1, 24, 1024) ['spotify:episode:2ltruy6bKnsYtFDfLMlO6E'] 116.27834868431091
# 363 (1, 26, 1024) ['spotify:episode:7f66EDdSeqSucUEncmT8hg'] 116.60473394393921
# 364 (1, 40, 1024) ['spotify:episode:1N0Tj6vmrxfYWubS0eA0hj'] 117.09533309936523
# 365 (1, 14, 1024) ['spotify:episode:0yHswchtLbrgT9Av2Zx4zy'] 117.2374153137207
# 366 (1, 55, 1024) ['spotify:episode:0eYDYnHQxVRYsvnGav6RKW'] 117.9223780632019
# 367 (1, 57, 1024) ['spotify:episode:0bmAYEtB7OBEMAZId0hrrS'] 118.58415603637695
# 368 (1, 36, 1024) ['spotify:episode:4Hamv0DE98QclvRKNDr3dC'] 118.94991827011108
# 369 (1, 17, 1024) ['spotify:episode:7ssR4KyjPBcmZtXXygtdiH'] 119.1205689907074
# 370 (1, 4, 1024) ['spotify:episode:42PU8079HT7DvGmUwkDkKj'] 119.16455721855164
# 371 (1, 12, 1024) ['spotify:episode:04hqYRWoyVcUMSqORHM9nO'] 119.29236006736755
# 372 (1, 18, 1024) ['spotify:episode:0NAOyVdLVOxHqLV7wbnO4f'] 119.4707863330841
# 373 (1, 15, 1024) ['spotify:episode:153HMeGs6dIETk8vOAopxT'] 119.6142098903656
# 374 (1, 15, 1024) ['spotify:episode:4ipRxkvqili6x6WHHpRuFC'] 119.75733852386475
# 375 (1, 14, 1024) ['spotify:episode:58TOwJRt1WFBP5YM78mUfn'] 119.89011240005493
# 376 (1, 10, 1024) ['spotify:episode:7yR36PTGINTZIvNte46qW1'] 119.9829466342926
# 377 (1, 26, 1024) ['spotify:episode:2Xeg8BOxRCQMxQJNkRKNQg'] 120.24644494056702
# 378 (1, 45, 1024) ['spotify:episode:3fF8Q9rM8xvgmUzaIbdpDm'] 120.72286176681519
# 379 (1, 29, 1024) ['spotify:episode:7KB1JOmAFCxqPutLo7EXTU'] 120.99714946746826
# 380 (1, 35, 1024) ['spotify:episode:54xfMw2EAX6kfbhBdExeAq'] 121.32307696342468
# 381 (1, 12, 1024) ['spotify:episode:0Q5bVkfjtdM02XqYGdXDH6'] 121.44720411300659
# 382 (1, 13, 1024) ['spotify:episode:7lc28xmGlKOlaUDcfuu6lH'] 121.57617402076721
# 383 (1, 41, 1024) ['spotify:episode:1yolB689xyi7NV8LE36c6c'] 121.94204473495483
# 384 (1, 23, 1024) ['spotify:episode:4zPxQwB2a7Ih8FBkjpE361'] 122.15961527824402
# 385 (1, 1, 1024) ['spotify:episode:2lFZiRb8kRnGKyptU6Yebr'] 122.17950201034546
# 386 (1, 4, 1024) ['spotify:episode:2qS40mTcLxDKLoaQVs8H9a'] 122.22239971160889
# 387 (1, 27, 1024) ['spotify:episode:4wRy51U0uLD4ZUqyFWavB4'] 122.50227665901184
# 388 (1, 12, 1024) ['spotify:episode:31zwa4EUbVrp5YHaJscZOj'] 122.6295793056488
# 389 (1, 37, 1024) ['spotify:episode:2fKv4vfiIYV0DkteofeSkI'] 123.0707380771637
# 390 (1, 1, 1024) ['spotify:episode:2a1FiJixYsXIV7iiW6USsm'] 123.09242153167725
# 391 (1, 1, 1024) ['spotify:episode:6WYuI0Ta7Rdw4WaPs0XxaG'] 123.11699223518372
# 392 (1, 67, 1024) ['spotify:episode:4CYbUty2sMCPMZ8eWYpdS8'] 124.00253653526306
# 393 (1, 32, 1024) ['spotify:episode:57xexf6NJ0SV7ckVT78uXO'] 124.43221521377563
# 394 (1, 60, 1024) ['spotify:episode:3i4qZ6FqzXdj8UiMeuaX3q'] 125.14785265922546
# 395 (1, 62, 1024) ['spotify:episode:6mmxGBhQoZw5iIrngZaAG4'] 125.79687738418579
# 396 (1, 13, 1024) ['spotify:episode:6WocMgpmLznMedEmM7yTIS'] 125.92879223823547
# 397 (1, 37, 1024) ['spotify:episode:0Dir3FgaqfuUvyADWcWfCS'] 126.30298686027527
# 398 (1, 13, 1024) ['spotify:episode:1tE1GAJjMNwjseopd47zxR'] 126.44217491149902
# 399 (1, 37, 1024) ['spotify:episode:2skQM6x6IABVPJIvQO9R25'] 126.81294703483582
# 400 (1, 4, 1024) ['spotify:episode:5EolNUtoexjBBAoVj5Ppy0'] 126.85510230064392
# 401 (1, 67, 1024) ['spotify:episode:4bEhbAZDCOQsYAyZQuk1q3'] 127.59181880950928
# 402 (1, 66, 1024) ['spotify:episode:5pmDmo87UK9lIMrMNv0mAD'] 128.35196208953857
# 403 (1, 72, 1024) ['spotify:episode:2UZfoZ7RAxgUNZJc9vWNY0'] 129.13512754440308
# 404 (1, 9, 1024) ['spotify:episode:6MXK2AKPrlGtcDQCKeZr37'] 129.23194932937622
# 405 (1, 51, 1024) ['spotify:episode:2Y8jc5V7n6TUyF5gFXzr5C'] 129.82660746574402
# 406 (1, 22, 1024) ['spotify:episode:2Y9ZsvPmmCBm2ae9GbcKQF'] 130.05920720100403
# 407 (1, 18, 1024) ['spotify:episode:6OHEPefRHqT6hQBZJKdNXK'] 130.28381633758545
# 408 (1, 50, 1024) ['spotify:episode:0OZhDk7RpBLX0p44ZbNR1t'] 130.8016529083252
# 409 (1, 13, 1024) ['spotify:episode:3ZfMYPNaFhwA7mFsWbTxw8'] 130.94310021400452
# 410 (1, 12, 1024) ['spotify:episode:4oQZAcd6xnxVA1e2GWaIFb'] 131.0719120502472
# 411 (1, 50, 1024) ['spotify:episode:4f77NE84uoy852WPcUOlES'] 131.54335284233093
# 412 (1, 24, 1024) ['spotify:episode:6YRwa1i0jf4mGVcWCkzZVw'] 131.77303409576416
# 413 (1, 7, 1024) ['spotify:episode:0kh6djI5bZQNdUrq045OT3'] 131.8547351360321
# 414 (1, 25, 1024) ['spotify:episode:6EMJ5mG8wghvZtGUd0ViAL'] 132.1116042137146
# 415 (1, 44, 1024) ['spotify:episode:3wSzVvzB53WyFg5DKxrK0l'] 132.561753988266
# 416 (1, 15, 1024) ['spotify:episode:1rPCEsRbJ9PZOm8K4FWSZj'] 132.73182821273804
# 417 (1, 15, 1024) ['spotify:episode:6wzrvh6GwhhlxGiTmRuWyO'] 132.87475037574768
# 418 (1, 26, 1024) ['spotify:episode:0Bz62IP340MItbN8KLKpAm'] 133.16468596458435
# 419 (1, 11, 1024) ['spotify:episode:5SOCsvDkmw8PjJJ95dl2oV'] 133.29142475128174
# 420 (1, 34, 1024) ['spotify:episode:3H7eFmLeSCd65lX4dAXIzZ'] 133.6214303970337
# 421 (1, 37, 1024) ['spotify:episode:081FoKeWRf8nzJi6MQFKRl'] 133.983948469162
# 422 (1, 3, 1024) ['spotify:episode:0GzToajGhX1K8OGAhN3Lww'] 134.02335405349731
# 423 (1, 47, 1024) ['spotify:episode:7ojzDdGYN6D1JFbQNMsIII'] 134.51412105560303
# 424 (1, 36, 1024) ['spotify:episode:0Pn9OeLCLriaY9hbYpIHPf'] 134.87978100776672
# 425 (1, 44, 1024) ['spotify:episode:0dQjvfoHWtVQhFOTHxv5CP'] 135.31506371498108
# 426 (1, 41, 1024) ['spotify:episode:207zX6EXtYWSBIt5OCFoDB'] 135.74627590179443
# 427 (1, 61, 1024) ['spotify:episode:6Od1ArXdGwUpL6CzvyuPHP'] 136.4611463546753
# 428 (1, 34, 1024) ['spotify:episode:0MVRk1RrVDUaXnO92oi7pV'] 136.84235858917236
# 429 (1, 28, 1024) ['spotify:episode:2zUVNVzOQQBue7PieuSQnj'] 137.1260585784912
# 430 (1, 26, 1024) ['spotify:episode:62O9hxuV4xnaZ9xbiPW5Ri'] 137.3953423500061
# 431 (1, 52, 1024) ['spotify:episode:7qaUdvEFwYUYYOX2Wa4Rp3'] 138.08133053779602
# 432 (1, 13, 1024) ['spotify:episode:261rYl6yPlUjl5immotbtV'] 138.25115537643433
# 433 (1, 28, 1024) ['spotify:episode:2Dxi8EnbWxGCgQaoxDqp9B'] 138.5711545944214
# 434 (1, 40, 1024) ['spotify:episode:5KQgYO80GmtPvpRCJWb6pa'] 138.96274042129517
# 435 (1, 44, 1024) ['spotify:episode:08RS6NQIGy9O2KyKVlCzdU'] 139.46103310585022
# 436 (1, 10, 1024) ['spotify:episode:5qHP8FrR6Mwq8h67l6VGzK'] 139.56096982955933
# 437 (1, 9, 1024) ['spotify:episode:6KpACKDBabgIadrIGocZVV'] 139.65845489501953
# 438 (1, 21, 1024) ['spotify:episode:4a3trVeENcM3dLnVJMntlc'] 139.9271330833435
# 439 (1, 11, 1024) ['spotify:episode:2LqAul73ymk5RhTPBtylkV'] 140.05223202705383
# 440 (1, 1, 1024) ['spotify:episode:020VZpYLp8NdRDibQXjpVY'] 140.08387088775635
# 441 (1, 11, 1024) ['spotify:episode:1OhV8h2qzqSTJsTbEoZ2g9'] 140.24773836135864
# 442 (1, 19, 1024) ['spotify:episode:2U8JEOKsWhQuQTgGCjomAd'] 140.50799751281738
# 443 (1, 16, 1024) ['spotify:episode:62T4xUjFEwcfcqPAW4g4j4'] 140.7389030456543
# 444 (1, 34, 1024) ['spotify:episode:5OmVWzrGndKY9FZFF2vUCL'] 141.19537568092346
# 445 (1, 38, 1024) ['spotify:episode:2qtYR4mTvGwbipZHPznqrX'] 141.74361658096313
# 446 (1, 46, 1024) ['spotify:episode:1GjzWFb5mT9lXCgSety6VH'] 142.39086365699768
# 447 (1, 21, 1024) ['spotify:episode:7q9CBXZmbLd6IfBrKRSkwh'] 142.62437677383423
# 448 (1, 13, 1024) ['spotify:episode:5y9cK5BvXDQ26DkfJsHw7P'] 142.76121640205383
# 449 (1, 24, 1024) ['spotify:episode:7eQWHIABJH51ssUAgCkzPg'] 143.0008420944214
# 450 (1, 27, 1024) ['spotify:episode:2DNDQrNmonn48KridZp5Gu'] 143.38070106506348
# 451 (1, 45, 1024) ['spotify:episode:4q9tqAlm8Q0JAmhFbBtEii'] 143.8611023426056
# 452 (1, 44, 1024) ['spotify:episode:2WhPRZEtiI5pTFVm7p3UX2'] 144.36448526382446
# 453 (1, 9, 1024) ['spotify:episode:4LQqm1DyMy3onnsxodMEzx'] 144.4609820842743
# 454 (1, 49, 1024) ['spotify:episode:1lXzKGIcWgMjWYIGJEg2bW'] 145.0839056968689
# 455 (1, 43, 1024) ['spotify:episode:4jHnCLXvE3NNTuOCwkH7qi'] 145.55211114883423
# 456 (1, 43, 1024) ['spotify:episode:0zHAfTbTclTiVKHDFTUNeu'] 146.002667427063
# 457 (1, 53, 1024) ['spotify:episode:3f7CQ3KLIJgnoK9ugkRiV5'] 146.49547863006592
# 458 (1, 39, 1024) ['spotify:episode:6Fze6WUioLqSOzdEME0T5U'] 146.875155210495
# 459 (1, 32, 1024) ['spotify:episode:0sdiTdxV9YADcBp1A8hQsl'] 147.21504998207092
# 460 (1, 41, 1024) ['spotify:episode:7Jcu2vnGXdyAyOciUrYvT8'] 147.60574507713318
# 461 (1, 5, 1024) ['spotify:episode:2XxwpvnMErxxv1gIE7kYn4'] 147.65310955047607
# 462 (1, 13, 1024) ['spotify:episode:6LZnJelH97Gffgz10RdetT'] 147.7907485961914
# 463 (1, 20, 1024) ['spotify:episode:0XVZslxawbMMiEfmL0Lyme'] 147.9853105545044
# 464 (1, 37, 1024) ['spotify:episode:3Vr6AUCTQgVWoE137b4IdB'] 148.39559674263
# 465 (1, 2, 1024) ['spotify:episode:44iIxNU8wzmvoAgxMrPpuj'] 148.42205381393433
# 466 (1, 2, 1024) ['spotify:episode:6W2ce6xVsDMc8Lp1cJM4V0'] 148.45134329795837
# 467 (1, 2, 1024) ['spotify:episode:6eRc7QmamYjcCYHWGUSpCj'] 148.47490429878235
# 468 (1, 10, 1024) ['spotify:episode:7cqVGapnPRreo3xEvAWjca'] 148.57067251205444
# 469 (1, 41, 1024) ['spotify:episode:3WuAyqc6CG1rMFCdSgYSL2'] 149.02392554283142
# 470 (1, 12, 1024) ['spotify:episode:4EbbBSwx3l6C6jbtvgjFsF'] 149.15970087051392
# 471 (1, 38, 1024) ['spotify:episode:0iO8qJH47AoUC2CBeln14R'] 149.55687284469604
# 472 (1, 25, 1024) ['spotify:episode:2j9s3Qr3BS9vO5gL4nU0Ug'] 149.80047821998596
# 473 (1, 2, 1024) ['spotify:episode:45hMVOlYDHoX0E92qKjKTW'] 149.8256697654724
# 474 (1, 2, 1024) ['spotify:episode:6BwubzSKN6LuxHoMa09f0n'] 149.85684943199158
# 475 (1, 28, 1024) ['spotify:episode:6ZaH6rTCPKXOWvlcbFx3u3'] 150.1503517627716
# 476 (1, 40, 1024) ['spotify:episode:6EpauezEPL5RhMgKd6covC'] 150.56053352355957
# 477 (1, 49, 1024) ['spotify:episode:3KOIKni13xmamjPWZ8WZEs'] 151.0939748287201
# 478 (1, 42, 1024) ['spotify:episode:0ydkmorWMUabHErinWLTM9'] 151.58304238319397
# 479 (1, 28, 1024) ['spotify:episode:4egFgLUr1ykjrgv2AJn9op'] 151.93533515930176
# 480 (1, 15, 1024) ['spotify:episode:3AcWng5pwo869l4MIHuSV0'] 152.11060214042664
# 481 (1, 28, 1024) ['spotify:episode:7nZ5Sg7mTcYY0hOKQlQhMx'] 152.40159845352173
# 482 (1, 59, 1024) ['spotify:episode:68f1rY0Urolyy3IYlsUPxd'] 153.13065481185913
# 483 (1, 19, 1024) ['spotify:episode:2GYOgtbIbjJsxDmgkP0ob6'] 153.32544207572937
# 484 (1, 17, 1024) ['spotify:episode:1rF6m0WvH3suCPX6Z72kPo'] 153.5003366470337
# 485 (1, 19, 1024) ['spotify:episode:4ehukOpFW7e3805TLaTEQA'] 153.69431233406067
# 486 (1, 34, 1024) ['spotify:episode:7AkJegM6EhKfDdCYApTBls'] 154.07764863967896
# 487 (1, 21, 1024) ['spotify:episode:3PqxJbf1J4QaYh8yqxgZQk'] 154.34659266471863
# 488 (1, 21, 1024) ['spotify:episode:3SCWH3EpXW7CNIEr9ItM1k'] 154.5414900779724
# 489 (1, 14, 1024) ['spotify:episode:2heyDaTfMQQx3uXnJlpR9V'] 154.69497203826904
# 490 (1, 19, 1024) ['spotify:episode:4Ip6tumAJ6VL26bojRxQVl'] 154.89047169685364
# 491 (1, 41, 1024) ['spotify:episode:4hpPS0w6NyfsELjVJINliB'] 155.32332968711853
# 492 (1, 21, 1024) ['spotify:episode:70XJryeCkTbxfSDXhiwvkk'] 155.5599503517151
# 493 (1, 37, 1024) ['spotify:episode:3vT0kFkz2Gz8RDLJH3knzx'] 155.96595358848572
# 494 (1, 7, 1024) ['spotify:episode:1vVyBd4Sq9zlPGOdItVgfC'] 156.04996728897095
# 495 (1, 15, 1024) ['spotify:episode:0rGqN62zfOmqU0eQ9AHuXi'] 156.22773623466492
# 496 (1, 8, 1024) ['spotify:episode:1MRseMufwdMFdwf9tAdQ9F'] 156.31816053390503
# 497 (1, 30, 1024) ['spotify:episode:1e4jQDoZSO6aCyZzuvNeu9'] 156.6223542690277
# 498 (1, 29, 1024) ['spotify:episode:2eJJmwnyOXVOc8vbkIy8El'] 156.9699192047119
# 499 (1, 27, 1024) ['spotify:episode:2h6p8z3CLHzkbRGX2hI5B8'] 157.24800205230713
# 500 (1, 30, 1024) ['spotify:episode:4xD8rmUOjlwL2RR5pRyy0m'] 157.58009099960327
# 501 (1, 34, 1024) ['spotify:episode:7J1iU1wEqpsbVhUs6Lp3B0'] 157.97200727462769
# 502 (1, 46, 1024) ['spotify:episode:5p18iupj3aQytap4Yul5L8'] 158.51488757133484
# 503 (1, 12, 1024) ['spotify:episode:1PDbp2SbU98zYd38Enu5tZ'] 158.66482591629028
# 504 (1, 13, 1024) ['spotify:episode:22gm6OrvlXrrJdfFn0sHHM'] 158.8129050731659
# 505 (1, 39, 1024) ['spotify:episode:1XplpPQ1jTNyiDWKzvtTV2'] 159.32247018814087
# 506 (1, 24, 1024) ['spotify:episode:4V6QMOrPFxkCXqUWpFW6L0'] 159.58472275733948
# 507 (1, 28, 1024) ['spotify:episode:1Jzr0NPKtscqfyNa08GGos'] 159.93171620368958
# 508 (1, 16, 1024) ['spotify:episode:76E1088jg23nRUbwrJAczM'] 160.13005471229553
# 509 (1, 21, 1024) ['spotify:episode:1fE39oSODbzEQt3u2mSC3K'] 160.34984588623047
# 510 (1, 52, 1024) ['spotify:episode:7tv49LY1R1SOydmvx6eMTr'] 161.08997583389282
# 511 (1, 40, 1024) ['spotify:episode:5KmWK8Qh5lsWIb2sUuJp4r'] 161.57399916648865
# 512 (1, 3, 1024) ['spotify:episode:0GnqEbMTBQyOGk7SCgBnFR'] 161.62674403190613
# 513 (1, 24, 1024) ['spotify:episode:4Noxr3gsD3nE8M6TN0opy4'] 161.92996263504028
# 514 (1, 75, 1024) ['spotify:episode:2wNztJ5bSIwddmuFKiXN4h'] 162.9772868156433
# 515 (1, 21, 1024) ['spotify:episode:4Defhf90gURxYkAyRp2oh3'] 163.28476786613464
# 516 (1, 60, 1024) ['spotify:episode:6EesVpPcL55oDP2zRr6qI9'] 163.9813323020935
# 517 (1, 4, 1024) ['spotify:episode:4jlPVIA5cQzgjZhGnkE1du'] 164.03089928627014
# 518 (1, 10, 1024) ['spotify:episode:3car2VxEIRSO41ImpxEgPu'] 164.16700649261475
# 519 (1, 14, 1024) ['spotify:episode:6zxQfih6safH4o6mB9bifY'] 164.3228464126587
# 520 (1, 12, 1024) ['spotify:episode:2hQUxoBiju6vmoltsNn23b'] 164.45012640953064
# 521 (1, 24, 1024) ['spotify:episode:1vkC26plEa16pnsp0tJJ93'] 164.75448656082153
# 522 (1, 67, 1024) ['spotify:episode:4Zk3YQE8QAX9aIcMTqZI1N'] 165.54357409477234
# 523 (1, 65, 1024) ['spotify:episode:4De26h9ngFo9bWB7MrIlxm'] 166.4123728275299
# 524 (1, 3, 1024) ['spotify:episode:5GDHyHd6rMLJEMhFutcLGd'] 166.46050834655762
# 525 (1, 60, 1024) ['spotify:episode:7iezniMOI6RpELZqArrFwL'] 167.19197607040405
# 526 (1, 23, 1024) ['spotify:episode:1QgWndnYGtv7EXi0UWYitW'] 167.45025038719177
# 527 (1, 27, 1024) ['spotify:episode:4jJzg0EzLII1x9KvnsjM8I'] 167.72948336601257
# 528 (1, 23, 1024) ['spotify:episode:4lATS5UINYOuSeR3Q9Dkt3'] 167.96103358268738
# 529 (1, 4, 1024) ['spotify:episode:5wRgB1PreTfm3t0ku6EGM0'] 168.0113503932953
# 530 (1, 34, 1024) ['spotify:episode:3VTEqJ93ElIHsORMEXSN9L'] 168.45592379570007
# 531 (1, 28, 1024) ['spotify:episode:1a8X3Df0CobqJNYPB4rCab'] 168.8120837211609
# 532 (1, 45, 1024) ['spotify:episode:5FwQJAdYq60tn39tfqJDTC'] 169.39925360679626
# 533 (1, 10, 1024) ['spotify:episode:129EpWpHc4eKrNpqI0yiUN'] 169.5186333656311
# 534 (1, 31, 1024) ['spotify:episode:6gmZyCefoOLjHf2jqx6Hn6'] 169.88912415504456
# 535 (1, 1, 1024) ['spotify:episode:3AnL6C1jqZjEbYKhgFmoOr'] 169.92422437667847
# 536 (1, 12, 1024) ['spotify:episode:6l0pWAfGA3mPjProWgqzNW'] 170.06135249137878
# 537 (1, 1, 1024) ['spotify:episode:1vpmTwn03rR6VMZZOv29KC'] 170.08905577659607
# 538 (1, 44, 1024) ['spotify:episode:7FvkZDKN5NkayU4dCsmVv3'] 170.74637269973755
# 539 (1, 11, 1024) ['spotify:episode:7g9MfLsbXPj3g8crL30ot0'] 170.9262933731079
# 540 (1, 40, 1024) ['spotify:episode:0oBuySv0mfQYcMaxlIHL5E'] 171.49955773353577
# 541 (1, 28, 1024) ['spotify:episode:2GBU0BOSFZX1fJgCGCliyB'] 171.90906953811646
# 542 (1, 28, 1024) ['spotify:episode:6YcxR3ZUSRX1ftr9YIjnyo'] 172.28910398483276
# 543 (1, 54, 1024) ['spotify:episode:3RwOY2BZlCJyuyvRWih1Ft'] 173.15934419631958
# 544 (1, 6, 1024) ['spotify:episode:6QtR8R7wMlhih0kSQ4Rfgw'] 173.23046970367432
# 545 (1, 7, 1024) ['spotify:episode:4YAqzEeXk5EVO8fwYzvuw7'] 173.3188898563385
# 546 (1, 12, 1024) ['spotify:episode:5GujnWH2rluXn1HEB5GEAm'] 173.46065521240234
# 547 (1, 23, 1024) ['spotify:episode:5X2Lx4D2hddPRdh1roWoz7'] 173.73274540901184
# 548 (1, 44, 1024) ['spotify:episode:6URm69QBcvJpqoGiTE1nyy'] 174.31908059120178
# 549 (1, 34, 1024) ['spotify:episode:3rNoYlx5xMRN3DbaXkqcWj'] 174.8142387866974
# 550 (1, 19, 1024) ['spotify:episode:3rVxOGWUKKI6cJtnN0hOrx'] 175.02558422088623
# 551 (1, 65, 1024) ['spotify:episode:05gIsdiumhzh7JjEhBELVr'] 176.01897048950195
# 552 (1, 12, 1024) ['spotify:episode:19DAzvki93rIhjuBFZP5J8'] 176.158940076828
# 553 (1, 12, 1024) ['spotify:episode:36WNABcbPlfAOAYqNiASDg'] 176.30934381484985
# 554 (1, 10, 1024) ['spotify:episode:6V7a0BfkNLSvRbvYTg9bop'] 176.45414876937866
# 555 (1, 34, 1024) ['spotify:episode:4fwcPeS80qSgLFr8SFendW'] 176.97890305519104
# 556 (1, 1, 1024) ['spotify:episode:06lTquWPAOVJexhZonvQCa'] 177.00132298469543
# 557 (1, 25, 1024) ['spotify:episode:2DFvNm0KQOKH9S87QnguWJ'] 177.32889580726624
# 558 (1, 28, 1024) ['spotify:episode:4TYGYvj8GmLoIpaGEKhCtL'] 177.8128638267517
# 559 (1, 47, 1024) ['spotify:episode:2wsNdhlBO1F6worsCWWtK1'] 178.5551793575287
# 560 (1, 40, 1024) ['spotify:episode:4m67vdseAx6vUET0gtzqfC'] 179.0732262134552
# 561 (1, 69, 1024) ['spotify:episode:7DcOwOSnGJLSM3WQzQS7WL'] 180.01869535446167
# 562 (1, 26, 1024) ['spotify:episode:1nngnyxLEC5YuDjgTuRrKr'] 180.41688919067383
# 563 (1, 30, 1024) ['spotify:episode:00DkMSm0fRH9TpwtvJL4N0'] 180.82845258712769
# 564 (1, 6, 1024) ['spotify:episode:5d92mQ5JC06YCt30OLF2di'] 180.92481184005737
# 565 (1, 44, 1024) ['spotify:episode:51edLg5olIdoPd24y4UMHS'] 181.5187919139862
# 566 (1, 48, 1024) ['spotify:episode:12R7FJ0NWy3uN9FafFqZk0'] 182.07629489898682
# 567 (1, 8, 1024) ['spotify:episode:281JOvJ9ESuKkfEg2VURKX'] 182.16879034042358
# 568 (1, 15, 1024) ['spotify:episode:6mNwrNcpawoHXzfsnJC4X3'] 182.3139727115631
# 569 (1, 4, 1024) ['spotify:episode:1ccF1WJijw4ePtWSciuIPv'] 182.36365246772766
# 570 (1, 3, 1024) ['spotify:episode:3UgnpOpPgqRFWIsA26wmPs'] 182.3985722064972
# 571 (1, 65, 1024) ['spotify:episode:5aHgJKHLTutOTuffw5tq8k'] 183.03824710845947
# 572 (1, 41, 1024) ['spotify:episode:6Ff4fAYJKXrnrxn3kKSreV'] 183.3985788822174
# 573 (1, 11, 1024) ['spotify:episode:6rO13qfRQxsbx7lEOb8qlH'] 183.51325011253357
# 574 (1, 12, 1024) ['spotify:episode:0o5VOh0CbpvQQrspTuAE1v'] 183.63361811637878
# 575 (1, 19, 1024) ['spotify:episode:1EUY0YMsUCReAi78xtVKeU'] 183.86058712005615
# 576 (1, 13, 1024) ['spotify:episode:05EF9y109a39kdWnc4caqg'] 184.01854181289673
# 577 (1, 10, 1024) ['spotify:episode:1IGWQ2uSXK2vhwZ7wVYLBp'] 184.1303572654724
# 578 (1, 40, 1024) ['spotify:episode:1neVpqWAyNM4dh2dCSxuIO'] 184.62641263008118
# 579 (1, 23, 1024) ['spotify:episode:6c8CUf4yhEOVWngNqd0x3N'] 184.91831135749817
# 580 (1, 59, 1024) ['spotify:episode:7jfOwPbLGiaxdn7v2aN20R'] 185.6754605770111
# 581 (1, 8, 1024) ['spotify:episode:6U1B38VXrbv63BW6FXC6l1'] 185.77881240844727
# 582 (1, 44, 1024) ['spotify:episode:1i5pgKU3VlqS8jiII1EZZL'] 186.43208527565002
# 583 (1, 30, 1024) ['spotify:episode:7Mbx8rO7Qa24Sek42ALJml'] 186.72832655906677
# 584 (1, 7, 1024) ['spotify:episode:6rhceBtvqFQinPbN5pHNDM'] 186.81841778755188
# 585 (1, 30, 1024) ['spotify:episode:1MvUF45vxZB9gsbCzmyPqQ'] 187.10325384140015
# 586 (1, 7, 1024) ['spotify:episode:45d1oaUGzLSiAF4t93e6Th'] 187.1821849346161
# 587 (1, 3, 1024) ['spotify:episode:0OK5TCyZMt08fFPcDDMDFc'] 187.2219524383545
# 588 (1, 60, 1024) ['spotify:episode:7MAxSJAfbtuUSIUo83Ut2y'] 187.7969844341278
# 589 (1, 9, 1024) ['spotify:episode:6AcpBIWUW4G3z69tVSnKzs'] 187.88981008529663
# 590 (1, 65, 1024) ['spotify:episode:5vsJPMuFWiFaeWs8jxp5Of'] 188.86354684829712
# 591 (1, 25, 1024) ['spotify:episode:4nDl3DTQox0VG0l6B0sBoE'] 189.21835494041443
# 592 (1, 21, 1024) ['spotify:episode:7H43kSWWXC70MFFVF4yGwL'] 189.51806616783142
# 593 (1, 24, 1024) ['spotify:episode:6J6EaddaonBhVZHHOtd4oA'] 189.79782056808472
# 594 (1, 36, 1024) ['spotify:episode:2IfLWSU98Gv8BbN2Ly9glh'] 190.29786276817322
# 595 (1, 15, 1024) ['spotify:episode:4YOq90opfiBsc3MwflzFbJ'] 190.47827219963074
# 596 (1, 34, 1024) ['spotify:episode:32fHsDixF5slILdXQWUzj8'] 190.85778546333313
# 597 (1, 60, 1024) ['spotify:episode:38tYe5KJzUHKfYKleWvqlC'] 191.4723298549652
# 598 (1, 43, 1024) ['spotify:episode:1n9EmyhffBSG0SQ9bBf1sq'] 191.90558886528015
# 599 (1, 42, 1024) ['spotify:episode:1RgnPIj7xYVWrVAgPrMk2e'] 192.36811470985413
# 600 (1, 19, 1024) ['spotify:episode:0HSHHiZJZfqDUYzfxpbdqc'] 192.56061434745789
# 601 (1, 19, 1024) ['spotify:episode:6aSwLl1newSyRfOOrjgJ8r'] 192.780433177948
# 602 (1, 44, 1024) ['spotify:episode:51I9lm4kh7jJuLW3OgGKnP'] 193.37820553779602
# 603 (1, 12, 1024) ['spotify:episode:1ichSKLHStnktdNFxZBTbc'] 193.53870368003845
# ...
# 827 (1, 16, 1024) ['spotify:episode:5if5L4wXYSLCdVxXQr5iGZ'] 265.08349800109863
# 828 (1, 52, 1024) ['spotify:episode:0IC1Chg2euBtX5HpLEx2a9'] 265.64341950416565
# 829 (1, 4, 1024) ['spotify:episode:4SGkaLYsGC84W6X1aqUuQg'] 265.6856882572174
# 830 (1, 4, 1024) ['spotify:episode:7cPZaaOm1YhmuT08RB4AFK'] 265.7373905181885
# 831 (1, 13, 1024) ['spotify:episode:1RjC39Ilch6rBJfFRBJMbj'] 265.87345933914185
# 832 (1, 10, 1024) ['spotify:episode:69xMTXfqvfRtiD2CPjqhtI'] 265.9976239204407
# 833 (1, 54, 1024) ['spotify:episode:4FHC1vhcTUyNpiIgGdzelu'] 266.5276870727539
# 834 (1, 10, 1024) ['spotify:episode:38xuJXidPowzolfgofJLSQ'] 266.6533570289612
# 835 (1, 50, 1024) ['spotify:episode:5pnBhbw50LJRDWTyb5EzMO'] 267.1610207557678
# 836 (1, 41, 1024) ['spotify:episode:45jGOJudJlne7IK3IQgxG0'] 267.5762984752655
# 837 (1, 7, 1024) ['spotify:episode:27Q1YQsidaCMmijL2OGsk4'] 267.6597626209259
# 838 (1, 25, 1024) ['spotify:episode:6Z4xLXaB9ilX9bIz14WIZb'] 267.8882796764374
# 839 (1, 30, 1024) ['spotify:episode:6ozhgcMOI6Qi9pUVyQUHWQ'] 268.14861392974854
# 840 (1, 31, 1024) ['spotify:episode:3dUqVb11w7Fq3kqc8euF0F'] 268.4798095226288
# 841 (1, 27, 1024) ['spotify:episode:5dHnbv7UpYFl39OzLihVzz'] 268.7596583366394
# 842 (1, 12, 1024) ['spotify:episode:0ITxiSvtV7pRBATd2cxepl'] 268.8882682323456
# 843 (1, 31, 1024) ['spotify:episode:3FZTVYGt1ng1v2CeMVwAfP'] 269.2333924770355
# 844 (1, 5, 1024) ['spotify:episode:2dm87P6iUkLd01xhNzqa02'] 269.2863857746124
# 845 (1, 12, 1024) ['spotify:episode:52HuSWEnX2m5zsZgBGzShf'] 269.4183485507965
# 846 (1, 40, 1024) ['spotify:episode:5IGfqI45we6zLqP3SdKYPV'] 269.83317279815674
# 847 (1, 47, 1024) ['spotify:episode:7fPIppDLk8ba5DdIv0WViS'] 270.3807134628296
# 848 (1, 58, 1024) ['spotify:episode:38ijvgTtLPjjnmCxkTzL0j'] 271.09328961372375
# 849 (1, 27, 1024) ['spotify:episode:4x0onsjaEKF4PO8f0nifrI'] 271.3629298210144
# 850 (1, 43, 1024) ['spotify:episode:0JejErbduV9QD5Dtgk4WwN'] 271.8659989833832
# 851 (1, 40, 1024) ['spotify:episode:4HlQN5gPTUgFAC1LyRJVN6'] 272.2798283100128
# 852 (1, 47, 1024) ['spotify:episode:3tqgxnDfHCcN9XK19dS5PR'] 272.79305267333984
# 853 (1, 16, 1024) ['spotify:episode:6jyaOoQ6aF3TB8z93Honak'] 272.9681158065796
# 854 (1, 6, 1024) ['spotify:episode:04xHi6OlXWxwnQUE66jH2i'] 273.052939414978
# 855 (1, 7, 1024) ['spotify:episode:2zqvtjZffDo5BHLHt3fLo0'] 273.13314414024353
# 856 (1, 14, 1024) ['spotify:episode:0K28aoL9zxb0TQDqdRKJPA'] 273.2731399536133
# 857 (1, 51, 1024) ['spotify:episode:0keuZkUaXgnaup0bX9cp4L'] 273.79308915138245
# 858 (1, 46, 1024) ['spotify:episode:0878cruQvQ3SEGJfe8h3SN'] 274.28298711776733
# 859 (1, 18, 1024) ['spotify:episode:4xndcPPVOmVbasZnXrXPB0'] 274.46309065818787
# 860 (1, 35, 1024) ['spotify:episode:1NR3nDeqb0dW7Vog00V5WJ'] 274.80997610092163
# 861 (1, 74, 1024) ['spotify:episode:7gE0StBDN4nfygEEaVsDta'] 275.5331017971039
# 862 (1, 3, 1024) ['spotify:episode:1F4hsSqn87iEttR0rA4tRS'] 275.5675222873688
# 863 (1, 24, 1024) ['spotify:episode:4QtxSjLPqjOH0Th0rGKgpy'] 275.786504983902
# 864 (1, 40, 1024) ['spotify:episode:3m48HJCNduhwAuGFkNXlrE'] 276.19264221191406
# 865 (1, 47, 1024) ['spotify:episode:3Nl0NNUKu1ut96Ub9lq1BH'] 276.66286444664
# 866 (1, 33, 1024) ['spotify:episode:6YIUuh6jh8WP6SAyvw2y1r'] 276.96791768074036
# 867 (1, 11, 1024) ['spotify:episode:3yveWKAwSF6rONBwHtikMC'] 277.0843257904053
# 868 (1, 55, 1024) ['spotify:episode:6HhDXN5Kjzi9cnl3Q2Pvzm'] 277.6728308200836
# 869 (1, 39, 1024) ['spotify:episode:3tcqpcoIDka9bsq0BBctQQ'] 278.1130132675171
# 870 (1, 51, 1024) ['spotify:episode:00y3rxCkHBrbY1xwqojEGR'] 278.70836997032166
# 871 (1, 62, 1024) ['spotify:episode:1cU24hYEUEwWWOra9Myvnx'] 279.47964453697205
# 872 (1, 32, 1024) ['spotify:episode:5214ErqOIK2cGVKXHjtlMT'] 279.85734367370605
# 873 (1, 48, 1024) ['spotify:episode:1Yhi0Zw6i7apBTf1YsEkck'] 280.40081691741943
# 874 (1, 20, 1024) ['spotify:episode:2lT5XVACAEXTkJsLoHxnOe'] 280.60270071029663
# 875 (1, 61, 1024) ['spotify:episode:7Jyh9A8kqxrvKfjjcBWn17'] 281.4024655818939
# 876 (1, 6, 1024) ['spotify:episode:5OmCBOADN4SVjsrAT39dGz'] 281.48737812042236
# 877 (1, 24, 1024) ['spotify:episode:6www1vKxYvMB8gK1gKMJ9T'] 281.74785590171814
# 878 (1, 57, 1024) ['spotify:episode:6j5KdEv6sWy842SxYzFDbM'] 282.46265029907227
# 879 (1, 6, 1024) ['spotify:episode:1eMrFBEvY9gaPhGB3YkM4T'] 282.53595519065857
# 880 (1, 33, 1024) ['spotify:episode:6fQYBv8xAgNS3gVaKLtB1J'] 282.93760418891907
# 881 (1, 27, 1024) ['spotify:episode:33dkjj1Bz9SXc6BKd4cDld'] 283.27921867370605
# 882 (1, 52, 1024) ['spotify:episode:4TNfvcrzPwiHl3jWzKnMOe'] 283.88244581222534
# 883 (1, 35, 1024) ['spotify:episode:0gL6Omy56nCLlIL786xYuC'] 284.23393082618713
# 884 (1, 32, 1024) ['spotify:episode:5lrXqwmskrsJKPiUyr7zkU'] 284.5791311264038
# 885 (1, 16, 1024) ['spotify:episode:3L0vLfEcOdepkZrnF7PDSc'] 284.7601544857025
# 886 (1, 17, 1024) ['spotify:episode:18DpTj7xworQJQIJPfZbi7'] 284.942565202713
# 887 (1, 3, 1024) ['spotify:episode:7vZyFSn0MbijdXDsZghZIL'] 284.98239731788635
# 888 (1, 33, 1024) ['spotify:episode:76sNJg3sTD8H3sYA1gFrK1'] 285.31165957450867
# 889 (1, 77, 1024) ['spotify:episode:0Gj8U5PWuzIMx3AQgwLkvj'] 286.2973771095276
# 890 (1, 33, 1024) ['spotify:episode:6NUmKdDzsUhU0QQGlALXEz'] 286.65722846984863
# 891 (1, 15, 1024) ['spotify:episode:6w72sFpoKZ0ddzWvXAnO0V'] 286.80323028564453
# 892 (1, 67, 1024) ['spotify:episode:2BkFlVpDnorNUKuTfFLbsm'] 287.5683958530426
# 893 (1, 12, 1024) ['spotify:episode:0OSLEfYrGShDSs7z98dCmL'] 287.6970314979553
# 894 (1, 2, 1024) ['spotify:episode:3oU1whPyefKnF8zSZBBAPB'] 287.7235701084137
# 895 (1, 2, 1024) ['spotify:episode:5llL5lw9iRIXRyDbmBsXhX'] 287.75230264663696
# 896 (1, 42, 1024) ['spotify:episode:4Wt9V2uTfg61q6qT0UzTEO'] 288.30355310440063
# 897 (1, 30, 1024) ['spotify:episode:00x6bXv5JPNTCDteN5JGlP'] 288.6572434902191
# 898 (1, 64, 1024) ['spotify:episode:3FogTK4hon2uQOqfi1eeAB'] 289.5623586177826
# 899 (1, 42, 1024) ['spotify:episode:1LGrOPH2MVCMrqB18TNtWZ'] 290.07932138442993
# 900 (1, 23, 1024) ['spotify:episode:07oEna1kHeEeoZ0JkJUMCp'] 290.32906222343445
# 901 (1, 30, 1024) ['spotify:episode:56l8IkHywESmocXWaRmChi'] 290.6532185077667
# 902 (1, 60, 1024) ['spotify:episode:6sJC5PDHcfOKGg2Oyz02ld'] 291.2833068370819
# 903 (1, 62, 1024) ['spotify:episode:32DrvZFCfE4oMYAXWmXXAD'] 291.9121298789978
# 904 (1, 39, 1024) ['spotify:episode:66fY3KMhJuOWZTHXgIUXBs'] 292.31259059906006
# 905 (1, 42, 1024) ['spotify:episode:3aUibXQfmgmzkRNJymPR7T'] 292.7699692249298
# 906 (1, 56, 1024) ['spotify:episode:1uuq1AlW55WuydoNPWQqF3'] 293.3631362915039
# 907 (1, 26, 1024) ['spotify:episode:6ZLneTgiOiizfmgsDtf3DL'] 293.63386964797974
# 908 (1, 29, 1024) ['spotify:episode:2f7QjbmcaeVRCSXlWPNmkX'] 293.91667079925537
# 909 (1, 14, 1024) ['spotify:episode:4Y2wwjbHqUGb993BxfPD4Y'] 294.055939912796
# 910 (1, 9, 1024) ['spotify:episode:12U3BJjMENejs7ljdo3Jz0'] 294.14650654792786
# 911 (1, 30, 1024) ['spotify:episode:6lDX2H4uYtvAXEWxfXZmEO'] 294.4318423271179
# 912 (1, 35, 1024) ['spotify:episode:52z5xB1zZTDGX0TkU0sIry'] 294.79421734809875
# 913 (1, 39, 1024) ['spotify:episode:5XcWZLuRWBefwLhMII2I5b'] 295.228013753891
# 914 (1, 24, 1024) ['spotify:episode:61XglL2xD7IEFEvUNDwBbl'] 295.47182750701904
# 915 (1, 25, 1024) ['spotify:episode:1bvUHB6JYgptSbaALWTRwR'] 295.727667093277
# 916 (1, 16, 1024) ['spotify:episode:5QauJYB9fy6CCv4xKIpHaY'] 295.8951840400696
# 917 (1, 61, 1024) ['spotify:episode:1n9RG0vlajXS2qevfEeKkO'] 296.6515347957611
# 918 (1, 12, 1024) ['spotify:episode:1PB1QjdVvioF6k7YKBKkQZ'] 296.78668427467346
# 919 (1, 8, 1024) ['spotify:episode:6LektbtRFWYNwUTgLMYtW3'] 296.88593316078186
# 920 (1, 10, 1024) ['spotify:episode:7y3NnO1yRteCxsyPXNCypt'] 297.02158546447754
# 921 (1, 17, 1024) ['spotify:episode:0m0ozPJzSHc3QYzoqz9mnS'] 297.21676993370056
# 922 (1, 52, 1024) ['spotify:episode:3MY3X341UrQo5AToAZjlpO'] 297.80233550071716
# 923 (1, 32, 1024) ['spotify:episode:1dKhwtbdugMkEQy4M8jUEV'] 298.1817829608917
# 924 (1, 39, 1024) ['spotify:episode:1hjsMwfmydIpcC1VzJLOh3'] 298.592449426651
# 925 (1, 52, 1024) ['spotify:episode:2JbcTwI4ffB0gNEDu8d3cE'] 299.2346181869507
# 926 (1, 20, 1024) ['spotify:episode:112ODcm7ePgi8yQZPYgJUD'] 299.43539547920227
# 927 (1, 25, 1024) ['spotify:episode:3zkN09hDZfoEeX6IfVNbvA'] 299.664452791214
# 928 (1, 1, 1024) ['spotify:episode:6ChNxIoe8gkovaVvs3LguH'] 299.69139099121094
# 929 (1, 50, 1024) ['spotify:episode:0vZrO84SbanI3W4NPfRam2'] 300.3014712333679
# 930 (1, 47, 1024) ['spotify:episode:5WWhk6Cldft2dR33GpGbXh'] 300.96868324279785
# 931 (1, 14, 1024) ['spotify:episode:56KU94hScVCfKhc2bl1jT4'] 301.1764373779297
# 932 (1, 13, 1024) ['spotify:episode:76WaXQnUbPkZ47jJgmNrIA'] 301.35341477394104
# 933 (1, 36, 1024) ['spotify:episode:18PMiOvbnWKCLSpyRFzVqo'] 301.7986693382263
# 934 (1, 20, 1024) ['spotify:episode:7ou727JYz9sQVwX1GohQ8M'] 302.00141429901123
# 935 (1, 2, 1024) ['spotify:episode:48ptdFmkAvFes3aGN6DF4W'] 302.03782391548157
# 936 (1, 23, 1024) ['spotify:episode:0TDR00NxPMlW1cXvWZxs2V'] 302.29621863365173
# 937 (1, 8, 1024) ['spotify:episode:0LRhMUlNYGLdK5uxTekou8'] 302.39151549339294
# 938 (1, 8, 1024) ['spotify:episode:4Z965BhWul0GYywMHohaXT'] 302.4821710586548
# 939 (1, 3, 1024) ['spotify:episode:5ryyAOoLdlhPOPd1fMHyFA'] 302.5237863063812
# 940 (1, 19, 1024) ['spotify:episode:5ElN9C6dXkxIDsJmo8AlA3'] 302.72272992134094
# 941 (1, 59, 1024) ['spotify:episode:5cZzm3PL9qKb2ybv3k4tZN'] 303.5112190246582
# 942 (1, 34, 1024) ['spotify:episode:3irXW0uYL3oxDY3zaQ3BMi'] 303.85128378868103
# 943 (1, 29, 1024) ['spotify:episode:5If27WyLTt3yp5jruRKnt2'] 304.1616177558899
# 944 (1, 3, 1024) ['spotify:episode:0Cy8io9QoM4iyCImBcke9t'] 304.2062168121338
# 945 (1, 3, 1024) ['spotify:episode:0gXNU5IOy7q1B5PmN0gZ56'] 304.2421374320984
# 946 (1, 3, 1024) ['spotify:episode:5HwoGdVEXZb3WYIp1HeKSq'] 304.28334736824036
# 947 (1, 24, 1024) ['spotify:episode:5i1RGplY1Vxq9hUESjtrUj'] 304.5293846130371
# 948 (1, 34, 1024) ['spotify:episode:5411rMTfvJFQ5OV7ioJXKi'] 304.89095735549927
# 949 (1, 21, 1024) ['spotify:episode:55lcvUUdtTaUbh77rs5nj9'] 305.1143777370453
# 950 (1, 23, 1024) ['spotify:episode:5t4aQysuMvTBL4a1aeWKPp'] 305.36091327667236
# 951 (1, 48, 1024) ['spotify:episode:1goqL2zrRwaz5Ru8kUwMJS'] 305.864294052124
# 952 (1, 32, 1024) ['spotify:episode:3nuj4rlpPTYHcbVgszb5uH'] 306.1982135772705
# 953 (1, 12, 1024) ['spotify:episode:6rLtKpBINzY4IhJ8mIrpee'] 306.3419454097748
# 954 (1, 2, 1024) ['spotify:episode:5GgPN5W11jI3rDOQDOsN8O'] 306.3755226135254
# 955 (1, 63, 1024) ['spotify:episode:5vqPkIcKTQI4oeTestwmRr'] 307.25320529937744
# 956 (1, 7, 1024) ['spotify:episode:6CJpYtArbPHYhdRdD7HGWp'] 307.3411407470703
# 957 (1, 14, 1024) ['spotify:episode:3hJ2aHpKYCyXm1496NCyyM'] 307.5036475658417
# 958 (1, 31, 1024) ['spotify:episode:6RyGVDftxDiKSU5aDWJd1E'] 307.9109492301941
# 959 (1, 65, 1024) ['spotify:episode:3jN182wreP26tNQjcEgyFY'] 308.5710611343384
# 960 (1, 5, 1024) ['spotify:episode:2jNGLxgJnBBhkl6BP0dRoJ'] 308.6207115650177
# 961 (1, 58, 1024) ['spotify:episode:0ScNgGeDidRrEtGZ5JF1ze'] 309.29207253456116
# 962 (1, 12, 1024) ['spotify:episode:0nTnGUIjhrlVQB9u5xNwea'] 309.41823387145996
# 963 (1, 21, 1024) ['spotify:episode:4N7XQ9t8ApWhfdONtrnCrU'] 309.6507692337036
# 964 (1, 6, 1024) ['spotify:episode:5BjgKDXBZRmM3rV8pCKG9U'] 309.73068046569824
# 965 (1, 6, 1024) ['spotify:episode:7gm6idH6glhcURmBCDNlxO'] 309.8133878707886
# 966 (1, 8, 1024) ['spotify:episode:0LvibgJ4sijXSGk8yUaj6G'] 309.90697383880615
# 967 (1, 30, 1024) ['spotify:episode:6d26iKO3X3g2HF0K1etnRe'] 310.22887563705444
# 968 (1, 20, 1024) ['spotify:episode:0yc2JazpzTlCfVZlX03Rum'] 310.42739629745483
# 969 (1, 29, 1024) ['spotify:episode:1nHxNDeaTI8iELomNsTBUR'] 310.7069420814514
# 970 (1, 40, 1024) ['spotify:episode:3onkN6EaPa860USdvgUp3O'] 311.1115400791168
# 971 (1, 13, 1024) ['spotify:episode:4d57DjmzeMV7rn5NWsiF3d'] 311.25091457366943
# 972 (1, 24, 1024) ['spotify:episode:1zQVBbWZnryIrSzrMyIsta'] 311.4986319541931
# 973 (1, 9, 1024) ['spotify:episode:5GEOY4fi9nfsayLhm2qW5h'] 311.5908999443054
# 974 (1, 17, 1024) ['spotify:episode:3zir6jx2t64H9gzWjg4ac0'] 311.7656445503235
# 975 (1, 20, 1024) ['spotify:episode:4wwo5VWMMYMIb43uMXeaMY'] 311.97844076156616
# 976 (1, 62, 1024) ['spotify:episode:2gViultpkndrFPEVQJ3pOK'] 312.7372007369995
# 977 (1, 24, 1024) ['spotify:episode:7K2lj087ShGgtMtxRiniiw'] 313.0608661174774
# 978 (1, 27, 1024) ['spotify:episode:57lcNxKLaJiTFCbIVCrfpb'] 313.39563393592834
# 979 (1, 8, 1024) ['spotify:episode:1U91Mj3wx0CCYbh1yddg5y'] 313.51747846603394
# 980 (1, 9, 1024) ['spotify:episode:4mPifYBI2B3UAkj0z9Q1oG'] 313.64229226112366
# 981 (1, 9, 1024) ['spotify:episode:5KNJcwdo2eSDR5Est1Jw2l'] 313.74074816703796
# 982 (1, 24, 1024) ['spotify:episode:2HIIKcJanvDmdYo9vNoUSO'] 314.02636885643005
# 983 (1, 5, 1024) ['spotify:episode:6HFF7GwVVHaHnUzxGLSIJt'] 314.0810868740082
# 984 (1, 61, 1024) ['spotify:episode:0W88qXL4QW5toLD7bCnJzt'] 314.712033033371
# 985 (1, 28, 1024) ['spotify:episode:0gF4f1rgZKbEETIb2aF1KF'] 314.9824628829956
# 986 (1, 19, 1024) ['spotify:episode:1rR66tJyzBLtsEnrxWrKdD'] 315.1715683937073
# 987 (1, 24, 1024) ['spotify:episode:6TAztFsHnWum0O87ePMuk7'] 315.41069650650024
# 988 (1, 32, 1024) ['spotify:episode:7GRoQSPKEoKG0UeeYxs1OX'] 315.7236647605896
# 989 (1, 14, 1024) ['spotify:episode:3u57dQEUl7W1YTCwQQTM6e'] 315.8670575618744
# 990 (1, 41, 1024) ['spotify:episode:0CaOGo6xSN51B2aLAQa1kU'] 316.25541162490845
# 991 (1, 23, 1024) ['spotify:episode:0FWVuA2iZZuqiMgo3puolf'] 316.4851188659668
# 992 (1, 19, 1024) ['spotify:episode:4phdz4uzWJkojLFYUwLHfh'] 316.67408418655396
# 993 (1, 17, 1024) ['spotify:episode:5ZaZBJN0mom9Zkok0gSadf'] 316.85508131980896
# 994 (1, 21, 1024) ['spotify:episode:72OE9HdC3ZkPOiZEBpNpHd'] 317.07071590423584
# 995 (1, 8, 1024) ['spotify:episode:2B2Q1RbBjK71DZ8M09IhJR'] 317.1522831916809
# 996 (1, 10, 1024) ['spotify:episode:5Rhg5tyVOmLEyp7tv2AmGV'] 317.2506904602051
# 997 (1, 39, 1024) ['spotify:episode:6ziiHalixsQpRQIx8iEn14'] 317.61538434028625
# 998 (1, 20, 1024) ['spotify:episode:0JTvIJIMxjQIpEQ833IhDh'] 317.8007161617279
# 999 (1, 17, 1024) ['spotify:episode:1ALqIYJIjmB73ldAbniX5N'] 317.97415018081665
# 1000 (1, 17, 1024) ['spotify:episode:37XyLgjVds2gNVU8e3SuTw'] 318.14315700531006
# 1001 (1, 73, 1024) ['spotify:episode:6xmPlp9kWXFhi4ljoCSpBq'] 319.05498242378235
# 1002 (1, 62, 1024) ['spotify:episode:63v1woR0GzbcjWLpv73qsO'] 319.78810691833496
# 1003 (1, 52, 1024) ['spotify:episode:2SFK4GMayBvPbeXC1FSASL'] 320.48017930984497
# 1004 (1, 17, 1024) ['spotify:episode:41Tvys3MKcIU0cPNU7eP5w'] 320.6603605747223
# 1005 (1, 9, 1024) ['spotify:episode:5MK07a5n2Z1xjI5NYRYGFX'] 320.7699489593506
# 1006 (1, 40, 1024) ['spotify:episode:3APrVn7DBJsy3pk7FpR2sw'] 321.25033259391785
# 1007 (1, 2, 1024) ['spotify:episode:44CnUZ2v4d6IWR1juH2I2F'] 321.27993726730347
# 1008 (1, 36, 1024) ['spotify:episode:3QE8qxHtJg3zMrq03R4GOj'] 321.7504155635834
# 1009 (1, 2, 1024) ['spotify:episode:4O147FcmvlvCjdFtrvhDdn'] 321.7820391654968
# 1010 (1, 3, 1024) ['spotify:episode:6tWkpJED4FjLM5vfo27bZS'] 321.82375621795654
# 1011 (1, 31, 1024) ['spotify:episode:7vQqvPasePM4hVlCvp2QQL'] 322.22497272491455
# 1012 (1, 5, 1024) ['spotify:episode:5xSMq1fCxp5RupWSHvv6mY'] 322.2749652862549
# 1013 (1, 75, 1024) ['spotify:episode:7eWetGg6xMuugGJw82nLT2'] 323.3715786933899
# 1014 (1, 23, 1024) ['spotify:episode:0EKaCL9rGymrGDaDG0EIhx'] 323.6822454929352
# 1015 (1, 38, 1024) ['spotify:episode:434ngZNf4auA40eI0ZFjaU'] 324.246217250824
# 1016 (1, 29, 1024) ['spotify:episode:4aGheKe4V1m8yLnCgCVv4S'] 324.59173822402954
# 1017 (1, 4, 1024) ['spotify:episode:2GeHhC1g8F5ybrriBvLPEi'] 324.6509280204773
# 1018 (1, 42, 1024) ['spotify:episode:77GdzmWIoYsV3LEUdipnvo'] 325.11000299453735
# 1019 (1, 2, 1024) ['spotify:episode:5nGrqVsmYEN88GChpccxrF'] 325.1398277282715
# 1020 (1, 14, 1024) ['spotify:episode:31u2KJ7szLvm5HPP6GgyYg'] 325.27976512908936
# 1021 (1, 28, 1024) ['spotify:episode:76g0MSenCR9SZdxCDaQXmB'] 325.5701394081116
# 1022 (1, 56, 1024) ['spotify:episode:6laf36slojw6EDeDqNso48'] 326.25030994415283
# 1023 (1, 37, 1024) ['spotify:episode:1t6R1TrR8D7kkKnFcuOD8A'] 326.6951491832733
# 1024 (1, 33, 1024) ['spotify:episode:1JnsLxgHqv9kv21D5bhIKy'] 327.1354784965515
# 1025 (1, 14, 1024) ['spotify:episode:6e6LyN7z8yusnDrqnE6Hm5'] 327.28435015678406
# 1026 (1, 3, 1024) ['spotify:episode:7qPPLigaXeKDzE9lUyNY91'] 327.32369470596313
# 1027 (1, 29, 1024) ['spotify:episode:1c42zpKBYn9HAROu65lqmY'] 327.6477768421173

# %%
# !python run.py --do_test --window_type token --kernel_size 256 --stride 256
# Out:
# ^C
